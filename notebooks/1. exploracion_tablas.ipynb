# %% [markdown]
# ## 0. Import packages

# %%
# data processing
import pandas as pd 
import numpy as np

# database agent
import psycopg2
from psycopg2 import OperationalError, errorcodes, errors

# env variables
import os
from dotenv import load_dotenv
load_dotenv()
database_credentials = {
    "username": os.getenv("DB_USERNAME"),
    "password": os.getenv("DB_PASSWORD")
}

# sys to add parent folder to path
import sys
sys.path.append("..")

from src.support_database_connection import connect_to_database

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# The purpose of this notebook is to explore the given datasets api_foursquare, df_aemet_final and municipios and to decide what columns to select, separate in a different table or to remove, to finally load them as tables to a database in PostgreSQL.

# %% [markdown]
# ## 2. Exploration

# %% [markdown]
# ### 2.1 Foursquare

# %% [markdown]
# Load and inspect the first rows of the dataset.

# %%
foursquare_df = pd.read_csv("../data/api_foursquare.csv", index_col = 0)
foursquare_df.head()
# Out:
#   municipio category                    fsq_id   closed_bucket  distance  \
# 0   ajalvir     Park  4d3c6c5b84d46ea87dddfd5c      LikelyOpen     563.0
# 1   ajalvir     Park  4f54f7bfe4b036244d02685b  VeryLikelyOpen    1724.0
# 2   ajalvir     Park  7d4ef99ca2dd4789f032a90c      LikelyOpen     333.0
# 3  alamo-el     Park  53de1144498e8fd8d8cb3537      LikelyOpen     118.0
# 4  alamo-el     Park  51a8f451498ecb8334de37df      LikelyOpen     582.0
#
#                                   link              name  \
# 0  /v3/places/4d3c6c5b84d46ea87dddfd5c       Diverjungla
# 1  /v3/places/4f54f7bfe4b036244d02685b   Parque Infantil
# 2  /v3/places/7d4ef99ca2dd4789f032a90c         Chiquitin
# 3  /v3/places/53de1144498e8fd8d8cb3537      Isla Perejil
# 4  /v3/places/51a8f451498ecb8334de37df  Parque de Madera
#
#                                              address   latitude  longitude
# 0  Calle Segovia, 20 (Pol. Ind. Donada), 28864 Aj...  40.529921  -3.484341
# 1                                                NaN  40.543867  -3.464773
# 2                                     Ajalvir Madrid  40.531662  -3.482835
# 3                 28607 El Alamo Comunidad de Madrid  40.230993  -3.991942
# 4                                                NaN  40.234636  -3.995166

# %% [markdown]
# Just looking at the values themselves does not give much information. Let's check datatypes and unique values.

# %%
foursquare_df.info()
print("\n-----")
for column in foursquare_df:
    print(f"Number of unique values per {column}: ", foursquare_df[column].nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 0 to 906
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   municipio      907 non-null    object
#  1   category       907 non-null    object
#  2   fsq_id         907 non-null    object
#  3   closed_bucket  907 non-null    object
#  4   distance       907 non-null    float64
#  5   link           907 non-null    object
#  6   name           907 non-null    object
#  7   address        778 non-null    object
#  8   latitude       907 non-null    float64
#  9   longitude      907 non-null    float64
# dtypes: float64(3), object(7)
# memory usage: 77.9+ KB
#
# -----
# Number of unique values per municipio:  96
# Number of unique values per category:  10
# Number of unique values per fsq_id:  822
# Number of unique values per closed_bucket:  3
# Number of unique values per distance:  724
# Number of unique values per link:  822
# Number of unique values per name:  764
# Number of unique values per address:  491
# Number of unique values per latitude:  811
# Number of unique values per longitude:  812

# %% [markdown]
# Observing value counts, there are fewer unique values of name and address, which means not all values are unique or there are missing values. Let's check the missing values and also group them by name to count their occurrences.

# %%
foursquare_df.isna().sum()
# Out:
# municipio          0
# category           0
# fsq_id             0
# closed_bucket      0
# distance           0
# link               0
# name               0
# address          129
# latitude           0
# longitude          0
# dtype: int64

# %% [markdown]
# Address is the only variable with missing values, and besides, they are not as many as to be able to explain why there are so much fewer unique values than expected for unique foursquare places. Therefore the need to check the value counts for each of these two features.

# %% [markdown]
# In the case of name, it might seem that in some cases the value inside is another category or subcategory, rather than a name.

# %%
foursquare_df["name"].value_counts().reset_index()[:15]
# Out:
#                              name  count
# 0                 Parque Infantil     19
# 1                          Parque     10
# 2                         Dog Run      6
# 3             Parque de la Marina      4
# 4                 Parque infantil      3
# 5         Parque Salvador Allende      3
# 6             Parque de la Tejera      3
# 7           Parque de Extremadura      3
# 8                Parque de Perros      3
# 9                       El Parque      3
# 10              Parque San Isidro      3
# 11          Parque de las Sombras      3
# 12               Cerro del Tambor      2
# 13           Parque de Sementales      2
# 14  Parque del Zoco las Pirámides      2

# %% [markdown]
# For example, for the same name Parque Infantil or Parque Salvador Allende there are several foursquare places. Looking at specific examples, it seems that there are places with generic names, but that belong to a different municipio.

# %%
filtro_name_isidro = foursquare_df["name"] == 'Dog Run'
foursquare_df[filtro_name_isidro]
# Out:
#                municipio category                    fsq_id closed_bucket  \
# 614   pozuelo-de-alarcon     Park  4d73f327e278f04d972751b8    LikelyOpen
# 647  rozas-de-madrid-las     Park  4bf7c792508c0f47c6f83d31    LikelyOpen
# 650  rozas-de-madrid-las     Park  4dac76534df01c19b1b4e626    LikelyOpen
# 657  rozas-de-madrid-las     Park  4ef0b5645c5ca1ec31296a30    LikelyOpen
# 662  rozas-de-madrid-las     Park  4cffffe70457b1f7a3d82e78        Unsure
# 664  rozas-de-madrid-las     Park  4d7e51b4555c59418322d077    LikelyOpen
#
#      distance                                 link     name  \
# 614    1196.0  /v3/places/4d73f327e278f04d972751b8  Dog Run
# 647     318.0  /v3/places/4bf7c792508c0f47c6f83d31  Dog Run
# 650     398.0  /v3/places/4dac76534df01c19b1b4e626  Dog Run
# 657     748.0  /v3/places/4ef0b5645c5ca1ec31296a30  Dog Run
# 662    1033.0  /v3/places/4cffffe70457b1f7a3d82e78  Dog Run
# 664    1180.0  /v3/places/4d7e51b4555c59418322d077  Dog Run
#
#                                           address   latitude  longitude
# 614  28224 Pozuelo de Alarcón Comunidad de Madrid  40.440103  -3.802633
# 647           28230 Las Rozas Comunidad de Madrid  40.493295  -3.872065
# 650           28231 Las Rozas Comunidad de Madrid  40.496604  -3.873975
# 657           28230 Las Rozas Comunidad de Madrid  40.496611  -3.883562
# 662           28231 Las Rozas Comunidad de Madrid  40.499341  -3.866536
# 664           28231 Las Rozas Comunidad de Madrid  40.491096  -3.862172

# %%
foursquare_df.query("name == 'Parque San Isidro'")
# Out:
#              municipio category                    fsq_id   closed_bucket  \
# 13   alcala-de-henares     Park  4d2da1b012d16a31ed5b2c22      LikelyOpen
# 276  cubas-de-la-sagra     Park  50092b66e4b0d0fe139abf11      LikelyOpen
# 794  torrejon-de-ardoz     Park  4cd5b1d02944b1f7f8ba5eec  VeryLikelyOpen
#
#      distance                                 link               name  \
# 13      726.0  /v3/places/4d2da1b012d16a31ed5b2c22  Parque San Isidro
# 276     813.0  /v3/places/50092b66e4b0d0fe139abf11  Parque San Isidro
# 794     556.0  /v3/places/4cd5b1d02944b1f7f8ba5eec  Parque San Isidro
#
#                                          address   latitude  longitude
# 13   28800 Alcalá de Henares Comunidad de Madrid  40.487883  -3.361226
# 276        Cubas de la Sagra Comunidad de Madrid  40.194303  -3.846270
# 794                            San Isidro Madrid  40.454914  -3.483518

# %% [markdown]
# In the case of addresses, it is clear that it is a problem of some addresses being incomplete.

# %%
foursquare_df["address"].value_counts().reset_index()
# Out:
#                                                address  count
# 0                                  Comunidad de Madrid     32
# 1                           Madrid Comunidad de Madrid     26
# 2                Alcalá de Henares Comunidad de Madrid     10
# 3                                               Madrid     10
# 4          28850 Torrejón de Ardoz Comunidad de Madrid      9
# ..                                                 ...    ...
# 486        28803 Alcalá de Henares Comunidad de Madrid      1
# 487        28800 Alcalá de Henares Comunidad de Madrid      1
# 488        28805 Alcalá de Henares Comunidad de Madrid      1
# 489        28806 Alcalá de Henares Comunidad de Madrid      1
# 490  Ronda Fiscal, 28804 Alcalá de Henares Comunida...      1
#
# [491 rows x 2 columns]

# %% [markdown]
# Finally, there must be duplicates, given that there are fewer unique values for fsq_id than rows.

# %%
foursquare_df[foursquare_df.duplicated("fsq_id",keep=False)].sort_values(by="fsq_id").head(6)
# Out:
#                       municipio  category                    fsq_id  \
# 714  san-lorenzo-de-el-escorial  Monument  09b5d18763e445d74c68f13a
# 297                 escorial-el  Monument  09b5d18763e445d74c68f13a
# 765  san-sebastian-de-los-reyes      Park  26daa0ca8eaf4c1b6f4be56c
# 104                  alcobendas      Park  26daa0ca8eaf4c1b6f4be56c
# 195                     braojos  Monument  4a470120ec564dc5ff1fae09
# 779          serna-del-monte-la  Monument  4a470120ec564dc5ff1fae09
#
#     closed_bucket  distance                                 link  \
# 714    LikelyOpen    1490.0  /v3/places/09b5d18763e445d74c68f13a
# 297    LikelyOpen    1333.0  /v3/places/09b5d18763e445d74c68f13a
# 765    LikelyOpen     981.0  /v3/places/26daa0ca8eaf4c1b6f4be56c
# 104    LikelyOpen     497.0  /v3/places/26daa0ca8eaf4c1b6f4be56c
# 195    LikelyOpen      72.0  /v3/places/4a470120ec564dc5ff1fae09
# 779    LikelyOpen    1735.0  /v3/places/4a470120ec564dc5ff1fae09
#
#                                        name                   address  \
# 714                 Estación de el Escorial  28280 El Escorial Madrid
# 297                 Estación de el Escorial  28280 El Escorial Madrid
# 765  Parque de Félix Rodríguez de la Fuente         Alcobendas Madrid
# 104  Parque de Félix Rodríguez de la Fuente         Alcobendas Madrid
# 195       Ayuntamiento Braojos de la Sierra            Braojos Madrid
# 779       Ayuntamiento Braojos de la Sierra            Braojos Madrid
#
#       latitude  longitude
# 714  40.585308  -4.132391
# 297  40.585308  -4.132391
# 765  40.544395  -3.637006
# 104  40.544395  -3.637006
# 195  41.039387  -3.642364
# 779  41.039387  -3.642364

# %% [markdown]
# After that check, it becomes clear that the town is not necessarily the town it belongs to. It could be that the closest town is actually the town where the location is in, or it could not and that column loses all its value altogether.
#
# The actual town could therefore be extracted from the address, although that requires manual labour.

# %%
foursquare_df = foursquare_df.sort_values(by="distance").drop_duplicates(subset="fsq_id", keep="first")

# %% [markdown]
# This dataset does not seem to need any database normalization performed to be uploaded as a table. To sum up:
# - municipio column: It could be dropped, but it is worth keeping for direct information that cannot be easily got from the coordinates or address without formatting.
# - distance: To drop. It provides only information about the distance to the town coordinates. The distance to the town of interest will be a calculated metric when necessary.
# - category column: Could be a separate table, but for the time being will stay on the same one. Separating it would just mean creating an id column for the sake of saving the space of repeating a category many times instead of an id, which is a fair point, but not considered enough justification.

# %% [markdown]
# ### 2.2 Aemet

# %% [markdown]
# Load and inspect the first rows of the dataset.

# %%
aemet_df = pd.read_csv("../data/df_aemet_final.csv")

aemet_df["fecha"] = pd.to_datetime(aemet_df["fecha"]) 

aemet_df.head()
# Out:
#                 fecha        cielo  temp._(°c)  sen._térmica_(°c)  \
# 0 2024-08-29 12:00:00  Nubes altas          21                 21
# 1 2024-08-29 13:00:00  Nubes altas          24                 24
# 2 2024-08-29 14:00:00   Muy nuboso          23                 23
# 3 2024-08-29 15:00:00  Nubes altas          23                 23
# 4 2024-08-29 16:00:00  Nubes altas          21                 21
#
#    racha_máx._(km/h)  precipitación_(mm)  nieve_(mm)  humedad_relativa_(%)  \
# 0               25.0                 0.0           0                    69
# 1               29.0                 0.0           0                    57
# 2               33.0                 0.0           0                    59
# 3               35.0                 0.0           0                    55
# 4               34.0                 0.0           0                    65
#
#   prob._precip.__(%)  prob._de_nieve_(%)  prob._de_tormenta_(%)  avisos  \
# 0                 95                   0                     75  Riesgo
# 1             Riesgo                   0                     75  Riesgo
# 2                100                   0                     80  Riesgo
# 3             Riesgo                   0                     80  Riesgo
# 4             Riesgo                   0                     80  Riesgo
#
#   dirección_viento  velocidad_del_viento     localizacion_id
# 0                S                     7  acebeda-la-id28001
# 1               SE                    12  acebeda-la-id28001
# 2                S                    14  acebeda-la-id28001
# 3                S                    17  acebeda-la-id28001
# 4                S                    20  acebeda-la-id28001

# %% [markdown]
# Inspecting the numerical datatypes, we can see that right now many of them do not have a lot of variability. That is explained by the fact that the data is not very extensive, coming from less than 2 days of data.

# %%
aemet_df.describe().T
# Out:
#                         count                           mean  \
# fecha                    7885  2024-08-30 09:28:27.545973504
# temp._(°c)             7885.0                      21.239062
# sen._térmica_(°c)      7885.0                      21.306024
# racha_máx._(km/h)      7885.0                      20.584147
# precipitación_(mm)     7885.0                       0.133621
# nieve_(mm)             7885.0                            0.0
# humedad_relativa_(%)   7885.0                      73.479899
# prob._de_nieve_(%)     7885.0                            0.0
# prob._de_tormenta_(%)  7885.0                      39.031706
# velocidad_del_viento   7885.0                      11.524794
#
#                                        min                  25%  \
# fecha                  2024-08-29 11:00:00  2024-08-29 22:00:00
# temp._(°c)                             9.0                 18.0
# sen._térmica_(°c)                      9.0                 18.0
# racha_máx._(km/h)                      1.0                 13.0
# precipitación_(mm)                     0.0                  0.0
# nieve_(mm)                             0.0                  0.0
# humedad_relativa_(%)                  34.0                 57.0
# prob._de_nieve_(%)                     0.0                  0.0
# prob._de_tormenta_(%)                  0.0                 10.0
# velocidad_del_viento                   0.0                  7.0
#
#                                        50%                  75%  \
# fecha                  2024-08-30 09:00:00  2024-08-30 20:00:00
# temp._(°c)                            20.0                 25.0
# sen._térmica_(°c)                     20.0                 25.0
# racha_máx._(km/h)                     19.0                 26.0
# precipitación_(mm)                     0.0                  0.0
# nieve_(mm)                             0.0                  0.0
# humedad_relativa_(%)                  76.0                 89.0
# prob._de_nieve_(%)                     0.0                  0.0
# prob._de_tormenta_(%)                 40.0                 65.0
# velocidad_del_viento                  11.0                 15.0
#
#                                        max        std
# fecha                  2024-08-31 07:00:00        NaN
# temp._(°c)                            32.0   4.317739
# sen._térmica_(°c)                     34.0    4.43552
# racha_máx._(km/h)                     83.0   9.904282
# precipitación_(mm)                    29.0   0.997648
# nieve_(mm)                             0.0        0.0
# humedad_relativa_(%)                 100.0  18.476987
# prob._de_nieve_(%)                     0.0        0.0
# prob._de_tormenta_(%)                 90.0  27.452468
# velocidad_del_viento                  45.0   6.032577

# %% [markdown]
# Categorical features seem interesting. Localizacion_id has the same amount of unique values as there are municipios. The features cielo, avisos and direccion viento are interesting.

# %%
aemet_df.describe(include="O")
# Out:
#               cielo prob._precip.__(%)      avisos dirección_viento  \
# count          7885               7885        7885             7885
# unique           23                 22           2                9
# top     Poco nuboso             Riesgo  Sin riesgo               NE
# freq           1442               4126        4296             2276
#
#          localizacion_id
# count               7885
# unique               179
# top     alcorcon-id28007
# freq                  45

# %% [markdown]
# Avisos does not seem to be a very objective data, as seen by the value counts and the head of the first registers, as it shows inconsistent criteria for riesgo.

# %%
display(aemet_df[["avisos","cielo"]].value_counts().reset_index().sort_values(by="cielo")[:10])
aemet_df.head()
# Out:
#         avisos                       cielo  count
# 33      Riesgo                       Bruma      3
# 29  Sin riesgo                       Bruma      7
# 2   Sin riesgo             Cielo despejado    643
# 12      Riesgo             Cielo despejado    219
# 1       Riesgo                    Cubierto    824
# 6   Sin riesgo                    Cubierto    493
# 28  Sin riesgo         Cubierto con lluvia      8
# 17      Riesgo         Cubierto con lluvia     80
# 22  Sin riesgo  Cubierto con lluvia escasa     34
# 13      Riesgo  Cubierto con lluvia escasa    196
#                 fecha        cielo  temp._(°c)  sen._térmica_(°c)  \
# 0 2024-08-29 12:00:00  Nubes altas          21                 21
# 1 2024-08-29 13:00:00  Nubes altas          24                 24
# 2 2024-08-29 14:00:00   Muy nuboso          23                 23
# 3 2024-08-29 15:00:00  Nubes altas          23                 23
# 4 2024-08-29 16:00:00  Nubes altas          21                 21
#
#    racha_máx._(km/h)  precipitación_(mm)  nieve_(mm)  humedad_relativa_(%)  \
# 0               25.0                 0.0           0                    69
# 1               29.0                 0.0           0                    57
# 2               33.0                 0.0           0                    59
# 3               35.0                 0.0           0                    55
# 4               34.0                 0.0           0                    65
#
#   prob._precip.__(%)  prob._de_nieve_(%)  prob._de_tormenta_(%)  avisos  \
# 0                 95                   0                     75  Riesgo
# 1             Riesgo                   0                     75  Riesgo
# 2                100                   0                     80  Riesgo
# 3             Riesgo                   0                     80  Riesgo
# 4             Riesgo                   0                     80  Riesgo
#
#   dirección_viento  velocidad_del_viento     localizacion_id
# 0                S                     7  acebeda-la-id28001
# 1               SE                    12  acebeda-la-id28001
# 2                S                    14  acebeda-la-id28001
# 3                S                    17  acebeda-la-id28001
# 4                S                    20  acebeda-la-id28001

# %% [markdown]
# Cielo is similar to category in the foursquare dataset. It provides qualitative value, but it is not worth separating it in a different table until there are specific characteristics to each cielo category.

# %%
aemet_df["cielo"].unique()
# Out:
# array(['Nubes altas', 'Muy nuboso',
#        'Cubierto con tormenta y lluvia escasa', 'Nuboso',
#        'Cielo despejado', 'Poco nuboso',
#        'Intervalos nubosos con lluvia escasa', 'Cubierto',
#        'Cubierto con lluvia escasa', 'Cubierto con lluvia',
#        'Muy nuboso con tormenta y lluvia escasa', 'Muy nuboso con lluvia',
#        'Intervalos nubosos', 'Muy nuboso con lluvia escasa',
#        'Nuboso con tormenta y lluvia escasa', 'Cubierto con tormenta',
#        'Nuboso con lluvia escasa', 'Intervalos nubosos con lluvia',
#        'Bruma', 'Niebla', 'Nuboso con lluvia', 'Muy nuboso con tormenta',
#        'Nuboso con tormenta'], dtype=object)

# %% [markdown]
# prob._precip.__(%) is also inconsistent, with mixed data types. What's more, looking up the source at Aemet's website, it registers data for a range of hours rather than hourly.
#
# Avisos and prob._precip.__(%) are to be dropped before uploading them to the database.

# %% [markdown]
# Finally, localizacion_id is a perfect column to create as a common id to join by the tables in the database.

# %% [markdown]
# ### 2.3 Municipios

# %% [markdown]
# Very straightforward in this case. This dataset could have the localizacion_id attached, to serve as the center of the database with foursquare and aemet at both sides.

# %%
municipios_df = pd.read_csv("../data/municipios.csv",index_col=0).T.reset_index()
municipios_df.columns = ["municipio_normalizado","latitude", "longitude","municipio"]
municipios_df
# Out:
#      municipio_normalizado    latitude   longitude              municipio
# 0               acebeda-la  41.0869583   -3.624399             La Acebeda
# 1                  ajalvir  40.5342302  -3.4807818                Ajalvir
# 2        alameda-del-valle  40.9177178  -3.8438216      Alameda del Valle
# 3                 alamo-el  40.2307296  -3.9905893               El Álamo
# 4        alcala-de-henares  40.4818396  -3.3644973      Alcalá de Henares
# ..                     ...         ...         ...                    ...
# 171        villar-del-olmo  40.3364465  -3.2355624        Villar del Olmo
# 172  villarejo-de-salvanes  40.1683582  -3.2738764  Villarejo de Salvanés
# 173   villaviciosa-de-odon  40.3573787  -3.9002334   Villaviciosa de Odón
# 174  villavieja-del-lozoya  41.0063622  -3.6716291  Villavieja del Lozoya
# 175              zarzalejo  40.5483016  -4.1815899              Zarzalejo
#
# [176 rows x 4 columns]

# %% [markdown]
# ## 3. Transformation and upload

# %% [markdown]
# ### 3.1 Transformation of tables

# %% [markdown]
# Let's start by the Aemet dataset, has it has the id that will be used to join all tables.

# %%
aemet_df[["municipio_normalizado","id_municipio"]] = aemet_df["localizacion_id"].str.extract(r'(.*)-(id\d{5})',expand=True)
aemet_df.drop(columns=["avisos","prob._precip.__(%)","localizacion_id"], inplace=True)
aemet_df.columns = ["fecha",  "cielo", "temp_celsius", "sen_termica_celsius", "racha_max_km_h", "precipitacion_mm", "nieve_mm", "humedad_relativa_pct", "prob_de_nieve_pct", "prob_de_tormenta_pct", "direccion_viento", "velocidad_viento","municipio_normalizado","id_municipio"]
aemet_df.head()
# Out:
#                 fecha        cielo  temp_celsius  sen_termica_celsius  \
# 0 2024-08-29 12:00:00  Nubes altas            21                   21
# 1 2024-08-29 13:00:00  Nubes altas            24                   24
# 2 2024-08-29 14:00:00   Muy nuboso            23                   23
# 3 2024-08-29 15:00:00  Nubes altas            23                   23
# 4 2024-08-29 16:00:00  Nubes altas            21                   21
#
#    racha_max_km_h  precipitacion_mm  nieve_mm  humedad_relativa_pct  \
# 0            25.0               0.0         0                    69
# 1            29.0               0.0         0                    57
# 2            33.0               0.0         0                    59
# 3            35.0               0.0         0                    55
# 4            34.0               0.0         0                    65
#
#    prob_de_nieve_pct  prob_de_tormenta_pct direccion_viento  velocidad_viento  \
# 0                  0                    75                S                 7
# 1                  0                    75               SE                12
# 2                  0                    80                S                14
# 3                  0                    80                S                17
# 4                  0                    80                S                20
#
#   municipio_normalizado id_municipio
# 0            acebeda-la      id28001
# 1            acebeda-la      id28001
# 2            acebeda-la      id28001
# 3            acebeda-la      id28001
# 4            acebeda-la      id28001

# %% [markdown]
# Now, the foursquare dataset can have:
# - The id_municipio attached.
# - The municipio variable dropped.
# - The distance variable dropped.

# %%
municipio_id = aemet_df[["id_municipio","municipio_normalizado"]].value_counts().reset_index()

# %%
foursquare_df_id = foursquare_df.merge(municipio_id[["id_municipio","municipio_normalizado"]], left_on="municipio", right_on="municipio_normalizado", how="inner")
foursquare_df_id.drop(columns=["municipio_normalizado","municipio","distance"], inplace=True)
foursquare_df_id
# Out:
#         category                    fsq_id   closed_bucket  \
# 0       Monument  03f82c6f2c134099b43faadc          Unsure
# 1       Monument  d52b434e8a2a45967eb0fcab      LikelyOpen
# 2           Park  4e481f77d4c065cb6bb5ecae      LikelyOpen
# 3       Monument  393a3d5770fc487b50c1ed69      LikelyOpen
# 4           Park  fdbc8d360b264c50faedf5a8          Unsure
# ..           ...                       ...             ...
# 817         Park  4f534690e4b028a9204243d1      LikelyOpen
# 818         Park  4dd6abc6d22d38ef42d5584a  VeryLikelyOpen
# 819         Park  4e9eab5d6c25364827a58c88  VeryLikelyOpen
# 820         Park  4ecfa77ecc219860f67f592c      LikelyOpen
# 821  Film Studio  5ea17cb293f6bd0008954bd5          Unsure
#
#                                     link  \
# 0    /v3/places/03f82c6f2c134099b43faadc
# 1    /v3/places/d52b434e8a2a45967eb0fcab
# 2    /v3/places/4e481f77d4c065cb6bb5ecae
# 3    /v3/places/393a3d5770fc487b50c1ed69
# 4    /v3/places/fdbc8d360b264c50faedf5a8
# ..                                   ...
# 817  /v3/places/4f534690e4b028a9204243d1
# 818  /v3/places/4dd6abc6d22d38ef42d5584a
# 819  /v3/places/4e9eab5d6c25364827a58c88
# 820  /v3/places/4ecfa77ecc219860f67f592c
# 821  /v3/places/5ea17cb293f6bd0008954bd5
#
#                                                   name  \
# 0    Sociedad Cooperativa Limitada el Encinar de Mi...
# 1               Casa Consistorial de Alcalá de Henares
# 2                                            El Parque
# 3                                         Semana Santa
# 4                                            Diverarte
# ..                                                 ...
# 817                      Parque Canino Parque Asturias
# 818                                       Prado Grande
# 819                                 Pinar de las Rozas
# 820                             Avd. del Mar Adriatico
# 821                                   The Blondes Pool
#
#                                                address   latitude  longitude  \
# 0    Pza. de España, 1, Miraflores de la Sierra Madrid  40.813749  -3.766791
# 1    Plaza de Cervantes, 12, 28801 Alcalá de Henare...  40.481808  -3.364352
# 2                                  Comunidad de Madrid  40.673340  -4.089480
# 3                                        28013  Madrid  40.500878  -4.238318
# 4    28750 San Agustín del Guadalix Comunidad de Ma...  40.679033  -3.616320
# ..                                                 ...        ...        ...
# 817                             Principado de Asturias  40.361813  -3.551802
# 818                                       Prado Madrid  40.578151  -3.951944
# 819                          Pinar Comunidad de Madrid  40.507475  -3.890129
# 820                                                NaN  40.175938  -3.687765
# 821  Calle Juan Alvarez Mendizabal, 79, 28008 Madri...  40.429866  -3.719693
#
#     id_municipio
# 0        id28085
# 1        id28005
# 2        id28068
# 3        id28125
# 4        id28129
# ..           ...
# 817      id28123
# 818      id28152
# 819      id28127
# 820      id28161
# 821      id28079
#
# [822 rows x 9 columns]

# %% [markdown]
# Finally, to add the id_municipio to the municipios table.

# %%
municipios_df = municipios_df.merge(municipio_id[["id_municipio","municipio_normalizado"]], on="municipio_normalizado", how="inner")
municipios_df
# Out:
#      municipio_normalizado    latitude   longitude              municipio  \
# 0               acebeda-la  41.0869583   -3.624399             La Acebeda
# 1                  ajalvir  40.5342302  -3.4807818                Ajalvir
# 2        alameda-del-valle  40.9177178  -3.8438216      Alameda del Valle
# 3                 alamo-el  40.2307296  -3.9905893               El Álamo
# 4        alcala-de-henares  40.4818396  -3.3644973      Alcalá de Henares
# ..                     ...         ...         ...                    ...
# 171        villar-del-olmo  40.3364465  -3.2355624        Villar del Olmo
# 172  villarejo-de-salvanes  40.1683582  -3.2738764  Villarejo de Salvanés
# 173   villaviciosa-de-odon  40.3573787  -3.9002334   Villaviciosa de Odón
# 174  villavieja-del-lozoya  41.0063622  -3.6716291  Villavieja del Lozoya
# 175              zarzalejo  40.5483016  -4.1815899              Zarzalejo
#
#     id_municipio
# 0        id28001
# 1        id28002
# 2        id28003
# 3        id28004
# 4        id28005
# ..           ...
# 171      id28179
# 172      id28180
# 173      id28181
# 174      id28182
# 175      id28183
#
# [176 rows x 5 columns]

# %% [markdown]
# ### 3.2 Upload

# %% [markdown]
# ### 3.2.1 Connection to the database

# %%
connection = connect_to_database("modulo4_lab3",credentials_dict=database_credentials)
cursor = connection.cursor()

# %% [markdown]
# ### 3.2.2 Creation of structure and tables

# %%
query_creation = """
CREATE TABLE IF NOT EXISTS municipios(
id_municipio VARCHAR(7) PRIMARY KEY,
municipio_normalizado VARCHAR(100) NOT NULL UNIQUE,
municipio VARCHAR(100) NOT NULL UNIQUE,
latitude DECIMAL,
longitude DECIMAL
);


CREATE TABLE IF NOT EXISTS foursquare_location(
fsq_id VARCHAR(200) PRIMARY KEY,
location_name VARCHAR (200) NOT NULL,
id_municipio VARCHAR(7),
closed_bucket VARCHAR(30),
category VARCHAR(100),
address VARCHAR(200),
latitude DECIMAL,
longitude DECIMAL,
link VARCHAR(200),
FOREIGN KEY (id_municipio) 
	REFERENCES municipios(id_municipio)
    ON DELETE RESTRICT
    ON UPDATE CASCADE
);

					
CREATE TABLE IF NOT EXISTS weather(
id_weather SERIAL PRIMARY KEY,
fecha TIMESTAMP NOT NULL,
id_municipio VARCHAR(7),
cielo VARCHAR(40), 
temp_celsius INT,
sen_termica_celsius INT,
racha_max_km_h DECIMAL,
precipitacion_mm DECIMAL,
nieve_mm DECIMAL (5,2),
humedad_relativa_pct DECIMAL,
prob_de_nieve_pct DECIMAL,
prob_de_tormenta_pct DECIMAL,
direccion_viento VARCHAR(2),
velocidad_viento INT,
FOREIGN KEY (id_municipio) 
	REFERENCES municipios(id_municipio)
    ON DELETE RESTRICT
    ON UPDATE CASCADE
);"""

cursor.execute(query_creation)
connection.commit()

# %% [markdown]
# ### 3.2.3 Data load

# %% [markdown]
# ##### 3.2.3.1 Municipio

# %%
aemet_df.head()
# Out:
#                 fecha        cielo  temp_celsius  sen_termica_celsius  \
# 0 2024-08-29 12:00:00  Nubes altas            21                   21
# 1 2024-08-29 13:00:00  Nubes altas            24                   24
# 2 2024-08-29 14:00:00   Muy nuboso            23                   23
# 3 2024-08-29 15:00:00  Nubes altas            23                   23
# 4 2024-08-29 16:00:00  Nubes altas            21                   21
#
#    racha_max_km_h  precipitacion_mm  nieve_mm  humedad_relativa_pct  \
# 0            25.0               0.0         0                    69
# 1            29.0               0.0         0                    57
# 2            33.0               0.0         0                    59
# 3            35.0               0.0         0                    55
# 4            34.0               0.0         0                    65
#
#    prob_de_nieve_pct  prob_de_tormenta_pct direccion_viento  velocidad_viento  \
# 0                  0                    75                S                 7
# 1                  0                    75               SE                12
# 2                  0                    80                S                14
# 3                  0                    80                S                17
# 4                  0                    80                S                20
#
#   municipio_normalizado id_municipio
# 0            acebeda-la      id28001
# 1            acebeda-la      id28001
# 2            acebeda-la      id28001
# 3            acebeda-la      id28001
# 4            acebeda-la      id28001

# %%
aemet_df[aemet_df["id_municipio"]=="id28030"].head(2)
# Out:
#                    fecha        cielo  temp_celsius  sen_termica_celsius  \
# 1278 2024-08-29 12:00:00   Muy nuboso            22                   22
# 1279 2024-08-29 13:00:00  Nubes altas            23                   23
#
#       racha_max_km_h  precipitacion_mm  nieve_mm  humedad_relativa_pct  \
# 1278            20.0               0.0         0                    74
# 1279            25.0               0.0         0                    67
#
#       prob_de_nieve_pct  prob_de_tormenta_pct direccion_viento  \
# 1278                  0                    75               SE
# 1279                  0                    75               SE
#
#       velocidad_viento municipio_normalizado id_municipio
# 1278                 6            cabrera-la      id28030
# 1279                 8            cabrera-la      id28030

# %%
municipios_order = ["id_municipio","municipio_normalizado","municipio","latitude","longitude"]

municipio_values = [tuple(value_row) for value_row in municipios_df[municipios_order].values]
municipio_values[:2]
# Out:
# [('id28001', 'acebeda-la', 'La Acebeda', '41.0869583', '-3.624399'),
#  ('id28002', 'ajalvir', 'Ajalvir', '40.5342302', '-3.4807818')]

# %%
query_insercion = """INSERT INTO municipios (id_municipio,municipio_normalizado,municipio,latitude,longitude) VALUES (%s,%s,%s,%s,%s);"""
cursor.executemany(query_insercion, municipio_values) # cuando se quieren insertar varios
connection.commit()

# %% [markdown]
# ##### 3.2.3.2 Foursquare_location

# %%
foursquare_order = ["fsq_id", "name", "id_municipio", "closed_bucket", "category", "address", "latitude", "longitude", "link"]

foursquare_values = [tuple(value_row) for value_row in foursquare_df_id[foursquare_order].values]
foursquare_values[0:2]
# Out:
# [('03f82c6f2c134099b43faadc',
#   'Sociedad Cooperativa Limitada el Encinar de Miraflores',
#   'id28085',
#   'Unsure',
#   'Monument',
#   'Pza. de España, 1, Miraflores de la Sierra Madrid',
#   40.813749,
#   -3.766791,
#   '/v3/places/03f82c6f2c134099b43faadc'),
#  ('d52b434e8a2a45967eb0fcab',
#   'Casa Consistorial de Alcalá de Henares',
#   'id28005',
#   'LikelyOpen',
#   'Monument',
#   'Plaza de Cervantes, 12, 28801 Alcalá de Henares Madrid',
#   40.481808,
#   -3.364352,
#   '/v3/places/d52b434e8a2a45967eb0fcab')]

# %%
query_insercion = """INSERT INTO foursquare_location (fsq_id, location_name, id_municipio, closed_bucket, category, address, latitude, longitude, link
) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s);"""
cursor.executemany(query_insercion, foursquare_values) # cuando se quieren insertar varios
connection.commit()

# %% [markdown]
# ##### 3.2.3.3 Weather

# %%
aemet_df = aemet_df[["fecha", "id_municipio", "cielo", "temp_celsius", "sen_termica_celsius", "racha_max_km_h", "precipitacion_mm", "nieve_mm", "humedad_relativa_pct", "prob_de_nieve_pct", "prob_de_tormenta_pct", "direccion_viento", "velocidad_viento"]]
aemet_df.head(2)
# Out:
#                 fecha id_municipio        cielo  temp_celsius  \
# 0 2024-08-29 12:00:00      id28001  Nubes altas            21
# 1 2024-08-29 13:00:00      id28001  Nubes altas            24
#
#    sen_termica_celsius  racha_max_km_h  precipitacion_mm  nieve_mm  \
# 0                   21            25.0               0.0         0
# 1                   24            29.0               0.0         0
#
#    humedad_relativa_pct  prob_de_nieve_pct  prob_de_tormenta_pct  \
# 0                    69                  0                    75
# 1                    57                  0                    75
#
#   direccion_viento  velocidad_viento
# 0                S                 7
# 1               SE                12

# %%
aemet_values = [tuple(value_row) for value_row in aemet_df.values]
aemet_values
# Out:
# [(Timestamp('2024-08-29 12:00:00'),
#   'id28001',
#   'Nubes altas',
#   21,
#   21,
#   25.0,
#   0.0,
#   0,
#   69,
#   0,
#   75,
#   'S',
#   7),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28001',
#   'Nubes altas',
#   24,
#   24,
#   29.0,
#   0.0,
#   0,
#   57,
#   0,
#   75,
#   'SE',
#   12),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28001',
#   'Muy nuboso',
#   23,
#   23,
#   33.0,
#   0.0,
#   0,
#   59,
#   0,
#   80,
#   'S',
#   14),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28001',
#   'Nubes altas',
#   23,
#   23,
#   35.0,
#   0.0,
#   0,
#   55,
#   0,
#   80,
#   'S',
#   17),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28001',
#   'Nubes altas',
#   21,
#   21,
#   34.0,
#   0.0,
#   0,
#   65,
#   0,
#   80,
#   'S',
#   20),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28001',
#   'Cubierto con tormenta y lluvia escasa',
#   21,
#   21,
#   35.0,
#   0.1,
#   0,
#   59,
#   0,
#   80,
#   'S',
#   17),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28001',
#   'Nuboso',
#   20,
#   20,
#   19.0,
#   0.0,
#   0,
#   65,
#   0,
#   80,
#   'S',
#   20),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28001',
#   'Nuboso',
#   19,
#   19,
#   27.0,
#   0.0,
#   0,
#   60,
#   0,
#   80,
#   'S',
#   9),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28001',
#   'Nuboso',
#   19,
#   19,
#   7.0,
#   0.0,
#   0,
#   46,
#   0,
#   45,
#   'S',
#   11),
#  (Timestamp('2024-08-29 21:00:00'),
#   'id28001',
#   'Nubes altas',
#   18,
#   18,
#   9.0,
#   0.0,
#   0,
#   52,
#   0,
#   45,
#   'NE',
#   4),
#  (Timestamp('2024-08-29 22:00:00'),
#   'id28001',
#   'Nubes altas',
#   17,
#   17,
#   10.0,
#   0.0,
#   0,
#   58,
#   0,
#   45,
#   'NO',
#   5),
#  (Timestamp('2024-08-29 23:00:00'),
#   'id28001',
#   'Cielo despejado',
#   16,
#   16,
#   9.0,
#   0.0,
#   0,
#   65,
#   0,
#   45,
#   'NO',
#   7),
#  (Timestamp('2024-08-30 00:00:00'),
#   'id28001',
#   'Poco nuboso',
#   15,
#   15,
#   6.0,
#   0.0,
#   0,
#   70,
#   0,
#   45,
#   'NO',
#   4),
#  (Timestamp('2024-08-30 01:00:00'),
#   'id28001',
#   'Intervalos nubosos con lluvia escasa',
#   15,
#   15,
#   13.0,
#   0.1,
#   0,
#   75,
#   0,
#   45,
#   'S',
#   4),
#  (Timestamp('2024-08-30 02:00:00'),
#   'id28001',
#   'Nubes altas',
#   14,
#   14,
#   13.0,
#   0.0,
#   0,
#   90,
#   0,
#   15,
#   'N',
#   6),
#  (Timestamp('2024-08-30 03:00:00'),
#   'id28001',
#   'Cielo despejado',
#   14,
#   14,
#   13.0,
#   0.0,
#   0,
#   100,
#   0,
#   15,
#   'N',
#   8),
#  (Timestamp('2024-08-30 04:00:00'),
#   'id28001',
#   'Poco nuboso',
#   14,
#   14,
#   9.0,
#   0.0,
#   0,
#   100,
#   0,
#   15,
#   'N',
#   8),
#  (Timestamp('2024-08-30 05:00:00'),
#   'id28001',
#   'Cubierto',
#   13,
#   13,
#   6.0,
#   0.0,
#   0,
#   100,
#   0,
#   15,
#   'N',
#   5),
#  (Timestamp('2024-08-30 06:00:00'),
#   'id28001',
#   'Cubierto',
#   13,
#   13,
#   6.0,
#   0.0,
#   0,
#   100,
#   0,
#   15,
#   'N',
#   4),
#  (Timestamp('2024-08-30 07:00:00'),
#   'id28001',
#   'Muy nuboso',
#   13,
#   13,
#   6.0,
#   0.0,
#   0,
#   100,
#   0,
#   15,
#   'NE',
#   4),
#  (Timestamp('2024-08-30 08:00:00'),
#   'id28001',
#   'Poco nuboso',
#   12,
#   12,
#   8.0,
#   0.0,
#   0,
#   100,
#   0,
#   70,
#   'N',
#   2),
#  (Timestamp('2024-08-30 09:00:00'),
#   'id28001',
#   'Poco nuboso',
#   15,
#   15,
#   17.0,
#   0.0,
#   0,
#   100,
#   0,
#   70,
#   'NO',
#   5),
#  (Timestamp('2024-08-30 10:00:00'),
#   'id28001',
#   'Cubierto',
#   17,
#   17,
#   22.0,
#   0.0,
#   0,
#   90,
#   0,
#   70,
#   'SE',
#   7),
#  (Timestamp('2024-08-30 11:00:00'),
#   'id28001',
#   'Cubierto con lluvia escasa',
#   19,
#   19,
#   35.0,
#   1.0,
#   0,
#   77,
#   0,
#   70,
#   'S',
#   11),
#  (Timestamp('2024-08-30 12:00:00'),
#   'id28001',
#   'Cubierto con lluvia',
#   21,
#   21,
#   30.0,
#   20.0,
#   0,
#   74,
#   0,
#   70,
#   'SE',
#   16),
#  (Timestamp('2024-08-30 13:00:00'),
#   'id28001',
#   'Cubierto con lluvia',
#   23,
#   23,
#   14.0,
#   3.0,
#   0,
#   59,
#   0,
#   70,
#   'E',
#   10),
#  (Timestamp('2024-08-30 14:00:00'),
#   'id28001',
#   'Intervalos nubosos con lluvia escasa',
#   24,
#   24,
#   15.0,
#   0.1,
#   0,
#   47,
#   0,
#   70,
#   'NO',
#   9),
#  (Timestamp('2024-08-30 15:00:00'),
#   'id28001',
#   'Nubes altas',
#   25,
#   25,
#   16.0,
#   0.0,
#   0,
#   44,
#   0,
#   70,
#   'SO',
#   7),
#  (Timestamp('2024-08-30 16:00:00'),
#   'id28001',
#   'Nubes altas',
#   25,
#   25,
#   11.0,
#   0.0,
#   0,
#   50,
#   0,
#   70,
#   'SE',
#   8),
#  (Timestamp('2024-08-30 17:00:00'),
#   'id28001',
#   'Poco nuboso',
#   26,
#   26,
#   13.0,
#   0.0,
#   0,
#   47,
#   0,
#   70,
#   'S',
#   5),
#  (Timestamp('2024-08-30 18:00:00'),
#   'id28001',
#   'Poco nuboso',
#   25,
#   25,
#   18.0,
#   0.0,
#   0,
#   49,
#   0,
#   70,
#   'SE',
#   6),
#  (Timestamp('2024-08-30 19:00:00'),
#   'id28001',
#   'Nubes altas',
#   24,
#   24,
#   12.0,
#   0.0,
#   0,
#   48,
#   0,
#   70,
#   'S',
#   10),
#  (Timestamp('2024-08-30 20:00:00'),
#   'id28001',
#   'Nuboso',
#   24,
#   24,
#   5.0,
#   0.0,
#   0,
#   58,
#   0,
#   20,
#   'S',
#   6),
#  (Timestamp('2024-08-30 21:00:00'),
#   'id28001',
#   'Poco nuboso',
#   21,
#   21,
#   5.0,
#   0.0,
#   0,
#   69,
#   0,
#   20,
#   'NO',
#   3),
#  (Timestamp('2024-08-30 22:00:00'),
#   'id28001',
#   'Poco nuboso',
#   19,
#   19,
#   6.0,
#   0.0,
#   0,
#   77,
#   0,
#   20,
#   'NO',
#   3),
#  (Timestamp('2024-08-30 23:00:00'),
#   'id28001',
#   'Poco nuboso',
#   16,
#   16,
#   6.0,
#   0.0,
#   0,
#   88,
#   0,
#   20,
#   'N',
#   4),
#  (Timestamp('2024-08-31 00:00:00'),
#   'id28001',
#   'Muy nuboso',
#   16,
#   16,
#   5.0,
#   0.0,
#   0,
#   88,
#   0,
#   20,
#   'O',
#   3),
#  (Timestamp('2024-08-31 01:00:00'),
#   'id28001',
#   'Nuboso',
#   16,
#   16,
#   7.0,
#   0.0,
#   0,
#   92,
#   0,
#   20,
#   'O',
#   2),
#  (Timestamp('2024-08-31 02:00:00'),
#   'id28001',
#   'Cielo despejado',
#   16,
#   16,
#   3.0,
#   0.0,
#   0,
#   96,
#   0,
#   0,
#   'SO',
#   3),
#  (Timestamp('2024-08-31 03:00:00'),
#   'id28001',
#   'Nuboso',
#   15,
#   15,
#   5.0,
#   0.0,
#   0,
#   96,
#   0,
#   0,
#   'C',
#   0),
#  (Timestamp('2024-08-31 04:00:00'),
#   'id28001',
#   'Poco nuboso',
#   14,
#   14,
#   3.0,
#   0.0,
#   0,
#   98,
#   0,
#   0,
#   'E',
#   3),
#  (Timestamp('2024-08-31 05:00:00'),
#   'id28001',
#   'Poco nuboso',
#   14,
#   14,
#   9.0,
#   0.0,
#   0,
#   97,
#   0,
#   0,
#   'NO',
#   1),
#  (Timestamp('2024-08-31 06:00:00'),
#   'id28001',
#   'Nuboso',
#   14,
#   14,
#   13.0,
#   0.0,
#   0,
#   93,
#   0,
#   0,
#   'NO',
#   6),
#  (Timestamp('2024-08-31 07:00:00'),
#   'id28001',
#   'Nubes altas',
#   13,
#   13,
#   10.0,
#   0.0,
#   0,
#   97,
#   0,
#   0,
#   'NO',
#   7),
#  (Timestamp('2024-08-29 12:00:00'),
#   'id28002',
#   'Cubierto con tormenta y lluvia escasa',
#   24,
#   24,
#   15.0,
#   0.1,
#   0,
#   64,
#   0,
#   70,
#   'E',
#   8),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28002',
#   'Cubierto con tormenta y lluvia escasa',
#   26,
#   26,
#   18.0,
#   0.1,
#   0,
#   57,
#   0,
#   70,
#   'E',
#   7),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28002',
#   'Nubes altas',
#   27,
#   27,
#   18.0,
#   0.0,
#   0,
#   51,
#   0,
#   75,
#   'E',
#   8),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28002',
#   'Muy nuboso',
#   28,
#   28,
#   21.0,
#   0.0,
#   0,
#   44,
#   0,
#   75,
#   'S',
#   7),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28002',
#   'Nubes altas',
#   27,
#   27,
#   40.0,
#   0.0,
#   0,
#   46,
#   0,
#   75,
#   'SO',
#   11),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28002',
#   'Cubierto',
#   25,
#   25,
#   14.0,
#   0.0,
#   0,
#   49,
#   0,
#   75,
#   'S',
#   25),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28002',
#   'Cubierto con tormenta y lluvia escasa',
#   26,
#   26,
#   65.0,
#   0.1,
#   0,
#   49,
#   0,
#   75,
#   'SO',
#   4),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28002',
#   'Muy nuboso con tormenta y lluvia escasa',
#   24,
#   24,
#   18.0,
#   0.3,
#   0,
#   48,
#   0,
#   75,
#   'O',
#   41),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28002',
#   'Nubes altas',
#   22,
#   22,
#   18.0,
#   0.0,
#   0,
#   54,
#   0,
#   65,
#   'NE',
#   13),
#  (Timestamp('2024-08-29 21:00:00'),
#   'id28002',
#   'Nubes altas',
#   21,
#   21,
#   23.0,
#   0.0,
#   0,
#   68,
#   0,
#   65,
#   'NE',
#   11),
#  (Timestamp('2024-08-29 22:00:00'),
#   'id28002',
#   'Cubierto con lluvia escasa',
#   20,
#   20,
#   17.0,
#   1.0,
#   0,
#   85,
#   0,
#   65,
#   'E',
#   9),
#  (Timestamp('2024-08-29 23:00:00'),
#   'id28002',
#   'Muy nuboso con lluvia',
#   20,
#   20,
#   24.0,
#   7.0,
#   0,
#   92,
#   0,
#   65,
#   'E',
#   5),
#  (Timestamp('2024-08-30 00:00:00'),
#   'id28002',
#   'Intervalos nubosos con lluvia escasa',
#   19,
#   19,
#   15.0,
#   0.8,
#   0,
#   86,
#   0,
#   65,
#   'N',
#   17),
#  (Timestamp('2024-08-30 01:00:00'),
#   'id28002',
#   'Cielo despejado',
#   19,
#   19,
#   18.0,
#   0.0,
#   0,
#   93,
#   0,
#   65,
#   'E',
#   9),
#  (Timestamp('2024-08-30 02:00:00'),
#   'id28002',
#   'Intervalos nubosos',
#   19,
#   19,
#   31.0,
#   0.0,
#   0,
#   96,
#   0,
#   20,
#   'N',
#   12),
#  (Timestamp('2024-08-30 03:00:00'),
#   'id28002',
#   'Intervalos nubosos',
#   18,
#   18,
#   26.0,
#   0.0,
#   0,
#   96,
#   0,
#   20,
#   'NE',
#   21),
#  (Timestamp('2024-08-30 04:00:00'),
#   'id28002',
#   'Intervalos nubosos',
#   18,
#   18,
#   21.0,
#   0.0,
#   0,
#   98,
#   0,
#   20,
#   'N',
#   16),
#  (Timestamp('2024-08-30 05:00:00'),
#   'id28002',
#   'Intervalos nubosos',
#   18,
#   18,
#   23.0,
#   0.0,
#   0,
#   100,
#   0,
#   20,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 06:00:00'),
#   'id28002',
#   'Intervalos nubosos',
#   18,
#   18,
#   30.0,
#   0.0,
#   0,
#   100,
#   0,
#   20,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 07:00:00'),
#   'id28002',
#   'Intervalos nubosos',
#   17,
#   17,
#   15.0,
#   0.0,
#   0,
#   100,
#   0,
#   20,
#   'NE',
#   18),
#  (Timestamp('2024-08-30 08:00:00'),
#   'id28002',
#   'Muy nuboso',
#   17,
#   17,
#   26.0,
#   0.0,
#   0,
#   100,
#   0,
#   25,
#   'N',
#   11),
#  (Timestamp('2024-08-30 09:00:00'),
#   'id28002',
#   'Muy nuboso',
#   19,
#   19,
#   22.0,
#   0.0,
#   0,
#   96,
#   0,
#   25,
#   'NE',
#   17),
#  (Timestamp('2024-08-30 10:00:00'),
#   'id28002',
#   'Cubierto',
#   22,
#   22,
#   26.0,
#   0.0,
#   0,
#   86,
#   0,
#   25,
#   'E',
#   13),
#  (Timestamp('2024-08-30 11:00:00'),
#   'id28002',
#   'Cubierto',
#   24,
#   24,
#   27.0,
#   0.0,
#   0,
#   78,
#   0,
#   25,
#   'SE',
#   18),
#  (Timestamp('2024-08-30 12:00:00'),
#   'id28002',
#   'Muy nuboso',
#   25,
#   25,
#   28.0,
#   0.0,
#   0,
#   55,
#   0,
#   25,
#   'NE',
#   6),
#  (Timestamp('2024-08-30 13:00:00'),
#   'id28002',
#   'Nubes altas',
#   26,
#   26,
#   36.0,
#   0.0,
#   0,
#   53,
#   0,
#   25,
#   'N',
#   14),
#  (Timestamp('2024-08-30 14:00:00'),
#   'id28002',
#   'Cubierto con lluvia escasa',
#   28,
#   29,
#   24.0,
#   0.1,
#   0,
#   51,
#   0,
#   50,
#   'N',
#   19),
#  (Timestamp('2024-08-30 15:00:00'),
#   'id28002',
#   'Cubierto con lluvia escasa',
#   28,
#   29,
#   19.0,
#   0.1,
#   0,
#   52,
#   0,
#   50,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 16:00:00'),
#   'id28002',
#   'Intervalos nubosos con lluvia escasa',
#   29,
#   29,
#   18.0,
#   0.1,
#   0,
#   48,
#   0,
#   50,
#   'NE',
#   10),
#  (Timestamp('2024-08-30 17:00:00'),
#   'id28002',
#   'Cubierto con lluvia escasa',
#   30,
#   31,
#   15.0,
#   0.1,
#   0,
#   52,
#   0,
#   50,
#   'NE',
#   10),
#  (Timestamp('2024-08-30 18:00:00'),
#   'id28002',
#   'Intervalos nubosos con lluvia escasa',
#   27,
#   28,
#   16.0,
#   0.1,
#   0,
#   62,
#   0,
#   50,
#   'NE',
#   9),
#  (Timestamp('2024-08-30 19:00:00'),
#   'id28002',
#   'Intervalos nubosos con lluvia escasa',
#   23,
#   23,
#   16.0,
#   0.1,
#   0,
#   73,
#   0,
#   50,
#   'NE',
#   11),
#  (Timestamp('2024-08-30 20:00:00'),
#   'id28002',
#   'Nubes altas',
#   24,
#   24,
#   11.0,
#   0.0,
#   0,
#   84,
#   0,
#   25,
#   'NE',
#   10),
#  (Timestamp('2024-08-30 21:00:00'),
#   'id28002',
#   'Nubes altas',
#   23,
#   23,
#   14.0,
#   0.0,
#   0,
#   88,
#   0,
#   25,
#   'NE',
#   8),
#  (Timestamp('2024-08-30 22:00:00'),
#   'id28002',
#   'Poco nuboso',
#   22,
#   22,
#   15.0,
#   0.0,
#   0,
#   90,
#   0,
#   25,
#   'N',
#   9),
#  (Timestamp('2024-08-30 23:00:00'),
#   'id28002',
#   'Cubierto',
#   21,
#   21,
#   13.0,
#   0.0,
#   0,
#   91,
#   0,
#   25,
#   'NE',
#   10),
#  (Timestamp('2024-08-31 00:00:00'),
#   'id28002',
#   'Muy nuboso',
#   20,
#   20,
#   9.0,
#   0.0,
#   0,
#   88,
#   0,
#   25,
#   'NE',
#   9),
#  (Timestamp('2024-08-31 01:00:00'),
#   'id28002',
#   'Muy nuboso',
#   20,
#   20,
#   10.0,
#   0.0,
#   0,
#   90,
#   0,
#   25,
#   'NE',
#   7),
#  (Timestamp('2024-08-31 02:00:00'),
#   'id28002',
#   'Cubierto',
#   20,
#   20,
#   9.0,
#   0.0,
#   0,
#   91,
#   0,
#   5,
#   'NE',
#   6),
#  (Timestamp('2024-08-31 03:00:00'),
#   'id28002',
#   'Poco nuboso',
#   19,
#   19,
#   13.0,
#   0.0,
#   0,
#   93,
#   0,
#   5,
#   'E',
#   6),
#  (Timestamp('2024-08-31 04:00:00'),
#   'id28002',
#   'Cielo despejado',
#   18,
#   18,
#   18.0,
#   0.0,
#   0,
#   92,
#   0,
#   5,
#   'NE',
#   9),
#  (Timestamp('2024-08-31 05:00:00'),
#   'id28002',
#   'Cielo despejado',
#   18,
#   18,
#   18.0,
#   0.0,
#   0,
#   96,
#   0,
#   5,
#   'N',
#   13),
#  (Timestamp('2024-08-31 06:00:00'),
#   'id28002',
#   'Cielo despejado',
#   17,
#   17,
#   9.0,
#   0.0,
#   0,
#   94,
#   0,
#   5,
#   'N',
#   11),
#  (Timestamp('2024-08-31 07:00:00'),
#   'id28002',
#   'Nubes altas',
#   17,
#   17,
#   10.0,
#   0.0,
#   0,
#   95,
#   0,
#   5,
#   'NE',
#   7),
#  (Timestamp('2024-08-29 12:00:00'),
#   'id28003',
#   'Muy nuboso',
#   23,
#   23,
#   23.0,
#   0.0,
#   0,
#   64,
#   0,
#   75,
#   'E',
#   6),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28003',
#   'Nubes altas',
#   26,
#   26,
#   28.0,
#   0.0,
#   0,
#   50,
#   0,
#   75,
#   'E',
#   8),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28003',
#   'Nubes altas',
#   25,
#   25,
#   35.0,
#   0.0,
#   0,
#   50,
#   0,
#   75,
#   'S',
#   12),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28003',
#   'Nubes altas',
#   24,
#   24,
#   35.0,
#   0.0,
#   0,
#   54,
#   0,
#   75,
#   'S',
#   15),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28003',
#   'Poco nuboso',
#   25,
#   25,
#   32.0,
#   0.0,
#   0,
#   48,
#   0,
#   75,
#   'S',
#   17),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28003',
#   'Muy nuboso con tormenta y lluvia escasa',
#   25,
#   25,
#   32.0,
#   0.1,
#   0,
#   50,
#   0,
#   75,
#   'S',
#   13),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28003',
#   'Cubierto',
#   22,
#   22,
#   37.0,
#   0.0,
#   0,
#   54,
#   0,
#   75,
#   'S',
#   15),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28003',
#   'Nubes altas',
#   19,
#   19,
#   14.0,
#   0.0,
#   0,
#   70,
#   0,
#   75,
#   'S',
#   18),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28003',
#   'Poco nuboso',
#   20,
#   20,
#   12.0,
#   0.0,
#   0,
#   43,
#   0,
#   50,
#   'O',
#   6),
#  (Timestamp('2024-08-29 21:00:00'),
#   'id28003',
#   'Intervalos nubosos con lluvia escasa',
#   18,
#   18,
#   10.0,
#   0.1,
#   0,
#   56,
#   0,
#   50,
#   'NO',
#   6),
#  (Timestamp('2024-08-29 22:00:00'),
#   'id28003',
#   'Poco nuboso',
#   16,
#   16,
#   11.0,
#   0.0,
#   0,
#   63,
#   0,
#   50,
#   'N',
#   4),
#  (Timestamp('2024-08-29 23:00:00'),
#   'id28003',
#   'Cielo despejado',
#   15,
#   15,
#   7.0,
#   0.0,
#   0,
#   69,
#   0,
#   50,
#   'NO',
#   6),
#  (Timestamp('2024-08-30 00:00:00'),
#   'id28003',
#   'Cielo despejado',
#   13,
#   13,
#   14.0,
#   0.0,
#   0,
#   75,
#   0,
#   50,
#   'NO',
#   3),
#  (Timestamp('2024-08-30 01:00:00'),
#   'id28003',
#   'Cielo despejado',
#   12,
#   12,
#   12.0,
#   0.0,
#   0,
#   78,
#   0,
#   50,
#   'E',
#   7),
#  (Timestamp('2024-08-30 02:00:00'),
#   'id28003',
#   'Poco nuboso',
#   13,
#   13,
#   15.0,
#   0.0,
#   0,
#   88,
#   0,
#   20,
#   'NO',
#   3),
#  (Timestamp('2024-08-30 03:00:00'),
#   'id28003',
#   'Poco nuboso',
#   12,
#   12,
#   13.0,
#   0.0,
#   0,
#   89,
#   0,
#   20,
#   'NO',
#   8),
#  (Timestamp('2024-08-30 04:00:00'),
#   'id28003',
#   'Poco nuboso',
#   12,
#   12,
#   11.0,
#   0.0,
#   0,
#   93,
#   0,
#   20,
#   'NO',
#   7),
#  (Timestamp('2024-08-30 05:00:00'),
#   'id28003',
#   'Poco nuboso',
#   12,
#   12,
#   9.0,
#   0.0,
#   0,
#   95,
#   0,
#   20,
#   'NO',
#   6),
#  (Timestamp('2024-08-30 06:00:00'),
#   'id28003',
#   'Poco nuboso',
#   12,
#   12,
#   8.0,
#   0.0,
#   0,
#   95,
#   0,
#   20,
#   'NO',
#   5),
#  (Timestamp('2024-08-30 07:00:00'),
#   'id28003',
#   'Muy nuboso',
#   12,
#   12,
#   8.0,
#   0.0,
#   0,
#   95,
#   0,
#   20,
#   'NO',
#   4),
#  (Timestamp('2024-08-30 08:00:00'),
#   'id28003',
#   'Cielo despejado',
#   11,
#   11,
#   8.0,
#   0.0,
#   0,
#   100,
#   0,
#   65,
#   'NO',
#   4),
#  (Timestamp('2024-08-30 09:00:00'),
#   'id28003',
#   'Cielo despejado',
#   15,
#   15,
#   14.0,
#   0.0,
#   0,
#   93,
#   0,
#   65,
#   'O',
#   3),
#  (Timestamp('2024-08-30 10:00:00'),
#   'id28003',
#   'Cubierto',
#   18,
#   18,
#   23.0,
#   0.0,
#   0,
#   77,
#   0,
#   65,
#   'SE',
#   5),
#  (Timestamp('2024-08-30 11:00:00'),
#   'id28003',
#   'Cubierto con lluvia',
#   21,
#   21,
#   25.0,
#   9.0,
#   0,
#   71,
#   0,
#   65,
#   'E',
#   10),
#  (Timestamp('2024-08-30 12:00:00'),
#   'id28003',
#   'Cubierto con lluvia',
#   23,
#   23,
#   29.0,
#   5.0,
#   0,
#   71,
#   0,
#   65,
#   'SE',
#   9),
#  (Timestamp('2024-08-30 13:00:00'),
#   'id28003',
#   'Cubierto con lluvia',
#   25,
#   25,
#   23.0,
#   3.0,
#   0,
#   54,
#   0,
#   65,
#   'S',
#   12),
#  (Timestamp('2024-08-30 14:00:00'),
#   'id28003',
#   'Intervalos nubosos con lluvia escasa',
#   27,
#   27,
#   8.0,
#   0.2,
#   0,
#   42,
#   0,
#   65,
#   'N',
#   11),
#  (Timestamp('2024-08-30 15:00:00'),
#   'id28003',
#   'Muy nuboso',
#   27,
#   27,
#   15.0,
#   0.0,
#   0,
#   45,
#   0,
#   65,
#   'S',
#   3),
#  (Timestamp('2024-08-30 16:00:00'),
#   'id28003',
#   'Nubes altas',
#   27,
#   27,
#   15.0,
#   0.0,
#   0,
#   44,
#   0,
#   65,
#   'SE',
#   6),
#  (Timestamp('2024-08-30 17:00:00'),
#   'id28003',
#   'Nubes altas',
#   28,
#   28,
#   20.0,
#   0.0,
#   0,
#   41,
#   0,
#   65,
#   'E',
#   5),
#  (Timestamp('2024-08-30 18:00:00'),
#   'id28003',
#   'Poco nuboso',
#   26,
#   26,
#   16.0,
#   0.0,
#   0,
#   39,
#   0,
#   65,
#   'SE',
#   8),
#  (Timestamp('2024-08-30 19:00:00'),
#   'id28003',
#   'Poco nuboso',
#   25,
#   25,
#   11.0,
#   0.0,
#   0,
#   43,
#   0,
#   65,
#   'E',
#   7),
#  (Timestamp('2024-08-30 20:00:00'),
#   'id28003',
#   'Poco nuboso',
#   24,
#   24,
#   12.0,
#   0.0,
#   0,
#   48,
#   0,
#   25,
#   'E',
#   3),
#  (Timestamp('2024-08-30 21:00:00'),
#   'id28003',
#   'Poco nuboso',
#   21,
#   21,
#   9.0,
#   0.0,
#   0,
#   55,
#   0,
#   25,
#   'NO',
#   7),
#  (Timestamp('2024-08-30 22:00:00'),
#   'id28003',
#   'Poco nuboso',
#   19,
#   19,
#   11.0,
#   0.0,
#   0,
#   67,
#   0,
#   25,
#   'NO',
#   5),
#  (Timestamp('2024-08-30 23:00:00'),
#   'id28003',
#   'Nuboso',
#   16,
#   16,
#   10.0,
#   0.0,
#   0,
#   77,
#   0,
#   25,
#   'NO',
#   6),
#  (Timestamp('2024-08-31 00:00:00'),
#   'id28003',
#   'Cubierto',
#   15,
#   15,
#   9.0,
#   0.0,
#   0,
#   81,
#   0,
#   25,
#   'NO',
#   6),
#  (Timestamp('2024-08-31 01:00:00'),
#   'id28003',
#   'Poco nuboso',
#   14,
#   14,
#   15.0,
#   0.0,
#   0,
#   85,
#   0,
#   25,
#   'NO',
#   4),
#  (Timestamp('2024-08-31 02:00:00'),
#   'id28003',
#   'Poco nuboso',
#   13,
#   13,
#   10.0,
#   0.0,
#   0,
#   93,
#   0,
#   0,
#   'N',
#   7),
#  (Timestamp('2024-08-31 03:00:00'),
#   'id28003',
#   'Poco nuboso',
#   12,
#   12,
#   11.0,
#   0.0,
#   0,
#   90,
#   0,
#   0,
#   'N',
#   5),
#  (Timestamp('2024-08-31 04:00:00'),
#   'id28003',
#   'Poco nuboso',
#   11,
#   11,
#   11.0,
#   0.0,
#   0,
#   93,
#   0,
#   0,
#   'N',
#   6),
#  (Timestamp('2024-08-31 05:00:00'),
#   'id28003',
#   'Cielo despejado',
#   12,
#   12,
#   14.0,
#   0.0,
#   0,
#   91,
#   0,
#   0,
#   'N',
#   5),
#  (Timestamp('2024-08-31 06:00:00'),
#   'id28003',
#   'Poco nuboso',
#   12,
#   12,
#   13.0,
#   0.0,
#   0,
#   89,
#   0,
#   0,
#   'NO',
#   7),
#  (Timestamp('2024-08-31 07:00:00'),
#   'id28003',
#   'Nubes altas',
#   12,
#   12,
#   10.0,
#   0.0,
#   0,
#   86,
#   0,
#   0,
#   'O',
#   7),
#  (Timestamp('2024-08-29 12:00:00'),
#   'id28004',
#   'Cubierto con lluvia escasa',
#   25,
#   25,
#   16.0,
#   0.1,
#   0,
#   55,
#   0,
#   60,
#   'E',
#   8),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28004',
#   'Intervalos nubosos con lluvia escasa',
#   27,
#   27,
#   16.0,
#   0.1,
#   0,
#   48,
#   0,
#   60,
#   'E',
#   6),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28004',
#   'Nubes altas',
#   28,
#   28,
#   18.0,
#   0.0,
#   0,
#   42,
#   0,
#   70,
#   'S',
#   7),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28004',
#   'Cubierto',
#   28,
#   28,
#   22.0,
#   0.0,
#   0,
#   40,
#   0,
#   70,
#   'S',
#   7),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28004',
#   'Nubes altas',
#   29,
#   29,
#   39.0,
#   0.0,
#   0,
#   37,
#   0,
#   70,
#   'S',
#   11),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28004',
#   'Cubierto con lluvia escasa',
#   29,
#   29,
#   58.0,
#   1.0,
#   0,
#   38,
#   0,
#   70,
#   'SE',
#   17),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28004',
#   'Intervalos nubosos con lluvia escasa',
#   27,
#   29,
#   25.0,
#   0.4,
#   0,
#   67,
#   0,
#   70,
#   'NO',
#   20),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28004',
#   'Muy nuboso',
#   25,
#   25,
#   17.0,
#   0.0,
#   0,
#   72,
#   0,
#   70,
#   'E',
#   17),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28004',
#   'Intervalos nubosos con lluvia escasa',
#   23,
#   23,
#   15.0,
#   0.1,
#   0,
#   87,
#   0,
#   55,
#   'N',
#   12),
#  (Timestamp('2024-08-29 21:00:00'),
#   'id28004',
#   'Poco nuboso',
#   21,
#   21,
#   19.0,
#   0.0,
#   0,
#   88,
#   0,
#   55,
#   'N',
#   9),
#  (Timestamp('2024-08-29 22:00:00'),
#   'id28004',
#   'Poco nuboso',
#   19,
#   19,
#   22.0,
#   0.0,
#   0,
#   99,
#   0,
#   55,
#   'NE',
#   13),
#  (Timestamp('2024-08-29 23:00:00'),
#   'id28004',
#   'Muy nuboso con lluvia escasa',
#   19,
#   19,
#   19.0,
#   0.1,
#   0,
#   82,
#   0,
#   55,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 00:00:00'),
#   'id28004',
#   'Muy nuboso',
#   19,
#   19,
#   17.0,
#   0.0,
#   0,
#   86,
#   0,
#   55,
#   'NE',
#   12),
#  (Timestamp('2024-08-30 01:00:00'),
#   'id28004',
#   'Poco nuboso',
#   19,
#   19,
#   19.0,
#   0.0,
#   0,
#   93,
#   0,
#   55,
#   'N',
#   12),
#  (Timestamp('2024-08-30 02:00:00'),
#   'id28004',
#   'Nubes altas',
#   18,
#   18,
#   21.0,
#   0.0,
#   0,
#   94,
#   0,
#   0,
#   'NE',
#   13),
#  (Timestamp('2024-08-30 03:00:00'),
#   'id28004',
#   'Cubierto',
#   18,
#   18,
#   24.0,
#   0.0,
#   0,
#   94,
#   0,
#   0,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 04:00:00'),
#   'id28004',
#   'Muy nuboso',
#   18,
#   18,
#   26.0,
#   0.0,
#   0,
#   90,
#   0,
#   0,
#   'NE',
#   17),
#  (Timestamp('2024-08-30 05:00:00'),
#   'id28004',
#   'Cielo despejado',
#   18,
#   18,
#   26.0,
#   0.0,
#   0,
#   92,
#   0,
#   0,
#   'NE',
#   18),
#  (Timestamp('2024-08-30 06:00:00'),
#   'id28004',
#   'Muy nuboso',
#   18,
#   18,
#   23.0,
#   0.0,
#   0,
#   94,
#   0,
#   0,
#   'NE',
#   18),
#  (Timestamp('2024-08-30 07:00:00'),
#   'id28004',
#   'Nuboso',
#   18,
#   18,
#   24.0,
#   0.0,
#   0,
#   95,
#   0,
#   0,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 08:00:00'),
#   'id28004',
#   'Muy nuboso',
#   18,
#   18,
#   22.0,
#   0.0,
#   0,
#   97,
#   0,
#   10,
#   'NE',
#   17),
#  (Timestamp('2024-08-30 09:00:00'),
#   'id28004',
#   'Cubierto',
#   20,
#   20,
#   27.0,
#   0.0,
#   0,
#   90,
#   0,
#   10,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 10:00:00'),
#   'id28004',
#   'Cubierto',
#   22,
#   22,
#   32.0,
#   0.0,
#   0,
#   81,
#   0,
#   10,
#   'E',
#   18),
#  (Timestamp('2024-08-30 11:00:00'),
#   'id28004',
#   'Muy nuboso',
#   24,
#   24,
#   33.0,
#   0.0,
#   0,
#   78,
#   0,
#   10,
#   'SE',
#   22),
#  (Timestamp('2024-08-30 12:00:00'),
#   'id28004',
#   'Nubes altas',
#   25,
#   25,
#   26.0,
#   0.0,
#   0,
#   64,
#   0,
#   10,
#   'E',
#   17),
#  (Timestamp('2024-08-30 13:00:00'),
#   'id28004',
#   'Nubes altas',
#   27,
#   28,
#   28.0,
#   0.0,
#   0,
#   63,
#   0,
#   10,
#   'NE',
#   18),
#  (Timestamp('2024-08-30 14:00:00'),
#   'id28004',
#   'Nuboso',
#   28,
#   29,
#   36.0,
#   0.0,
#   0,
#   57,
#   0,
#   45,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 15:00:00'),
#   'id28004',
#   'Nuboso',
#   29,
#   30,
#   32.0,
#   0.0,
#   0,
#   56,
#   0,
#   45,
#   'NE',
#   24),
#  (Timestamp('2024-08-30 16:00:00'),
#   'id28004',
#   'Nuboso',
#   30,
#   31,
#   24.0,
#   0.0,
#   0,
#   50,
#   0,
#   45,
#   'NE',
#   20),
#  (Timestamp('2024-08-30 17:00:00'),
#   'id28004',
#   'Poco nuboso',
#   31,
#   32,
#   21.0,
#   0.0,
#   0,
#   49,
#   0,
#   45,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 18:00:00'),
#   'id28004',
#   'Cielo despejado',
#   30,
#   32,
#   17.0,
#   0.0,
#   0,
#   56,
#   0,
#   45,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 19:00:00'),
#   'id28004',
#   'Nubes altas',
#   29,
#   31,
#   17.0,
#   0.0,
#   0,
#   62,
#   0,
#   45,
#   'NE',
#   10),
#  (Timestamp('2024-08-30 20:00:00'),
#   'id28004',
#   'Nuboso',
#   28,
#   30,
#   15.0,
#   0.0,
#   0,
#   67,
#   0,
#   5,
#   'NE',
#   12),
#  (Timestamp('2024-08-30 21:00:00'),
#   'id28004',
#   'Nubes altas',
#   26,
#   26,
#   20.0,
#   0.0,
#   0,
#   73,
#   0,
#   5,
#   'NE',
#   11),
#  (Timestamp('2024-08-30 22:00:00'),
#   'id28004',
#   'Nubes altas',
#   24,
#   24,
#   15.0,
#   0.0,
#   0,
#   80,
#   0,
#   5,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 23:00:00'),
#   'id28004',
#   'Poco nuboso',
#   21,
#   21,
#   14.0,
#   0.0,
#   0,
#   90,
#   0,
#   5,
#   'NE',
#   10),
#  (Timestamp('2024-08-31 00:00:00'),
#   'id28004',
#   'Poco nuboso',
#   21,
#   21,
#   15.0,
#   0.0,
#   0,
#   91,
#   0,
#   5,
#   'NE',
#   10),
#  (Timestamp('2024-08-31 01:00:00'),
#   'id28004',
#   'Muy nuboso',
#   21,
#   21,
#   17.0,
#   0.0,
#   0,
#   89,
#   0,
#   5,
#   'E',
#   11),
#  (Timestamp('2024-08-31 02:00:00'),
#   'id28004',
#   'Poco nuboso',
#   21,
#   21,
#   18.0,
#   0.0,
#   0,
#   84,
#   0,
#   5,
#   'E',
#   12),
#  (Timestamp('2024-08-31 03:00:00'),
#   'id28004',
#   'Nuboso',
#   20,
#   20,
#   19.0,
#   0.0,
#   0,
#   86,
#   0,
#   5,
#   'E',
#   11),
#  (Timestamp('2024-08-31 04:00:00'),
#   'id28004',
#   'Muy nuboso',
#   19,
#   19,
#   13.0,
#   0.0,
#   0,
#   85,
#   0,
#   5,
#   'NE',
#   13),
#  (Timestamp('2024-08-31 05:00:00'),
#   'id28004',
#   'Poco nuboso',
#   19,
#   19,
#   12.0,
#   0.0,
#   0,
#   87,
#   0,
#   5,
#   'NE',
#   8),
#  (Timestamp('2024-08-31 06:00:00'),
#   'id28004',
#   'Cielo despejado',
#   19,
#   19,
#   10.0,
#   0.0,
#   0,
#   90,
#   0,
#   5,
#   'N',
#   8),
#  (Timestamp('2024-08-31 07:00:00'),
#   'id28004',
#   'Nubes altas',
#   18,
#   18,
#   8.0,
#   0.0,
#   0,
#   90,
#   0,
#   5,
#   'NE',
#   6),
#  (Timestamp('2024-08-29 12:00:00'),
#   'id28005',
#   'Nuboso con tormenta y lluvia escasa',
#   25,
#   25,
#   18.0,
#   0.1,
#   0,
#   61,
#   0,
#   75,
#   'SE',
#   8),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28005',
#   'Intervalos nubosos con lluvia escasa',
#   27,
#   28,
#   18.0,
#   0.1,
#   0,
#   55,
#   0,
#   75,
#   'E',
#   7),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28005',
#   'Cubierto',
#   28,
#   28,
#   21.0,
#   0.0,
#   0,
#   46,
#   0,
#   80,
#   'E',
#   5),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28005',
#   'Cubierto',
#   29,
#   29,
#   35.0,
#   0.0,
#   0,
#   42,
#   0,
#   80,
#   'S',
#   8),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28005',
#   'Nubes altas',
#   27,
#   27,
#   37.0,
#   0.0,
#   0,
#   49,
#   0,
#   80,
#   'S',
#   21),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28005',
#   'Poco nuboso',
#   26,
#   26,
#   30.0,
#   0.0,
#   0,
#   47,
#   0,
#   80,
#   'S',
#   22),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28005',
#   'Cubierto',
#   27,
#   27,
#   30.0,
#   0.0,
#   0,
#   42,
#   0,
#   80,
#   'S',
#   15),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28005',
#   'Intervalos nubosos con lluvia escasa',
#   25,
#   25,
#   21.0,
#   0.8,
#   0,
#   46,
#   0,
#   80,
#   'S',
#   16),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28005',
#   'Muy nuboso',
#   23,
#   23,
#   18.0,
#   0.0,
#   0,
#   68,
#   0,
#   70,
#   'NE',
#   12),
#  (Timestamp('2024-08-29 21:00:00'),
#   'id28005',
#   'Cubierto',
#   22,
#   22,
#   24.0,
#   0.0,
#   0,
#   77,
#   0,
#   70,
#   'N',
#   9),
#  (Timestamp('2024-08-29 22:00:00'),
#   'id28005',
#   'Cubierto con tormenta',
#   21,
#   21,
#   38.0,
#   6.0,
#   0,
#   88,
#   0,
#   70,
#   'N',
#   9),
#  (Timestamp('2024-08-29 23:00:00'),
#   'id28005',
#   'Muy nuboso',
#   20,
#   20,
#   38.0,
#   0.0,
#   0,
#   96,
#   0,
#   70,
#   'NE',
#   17),
#  (Timestamp('2024-08-30 00:00:00'),
#   'id28005',
#   'Poco nuboso',
#   19,
#   19,
#   36.0,
#   0.0,
#   0,
#   97,
#   0,
#   70,
#   'E',
#   10),
#  (Timestamp('2024-08-30 01:00:00'),
#   'id28005',
#   'Cielo despejado',
#   19,
#   19,
#   22.0,
#   0.0,
#   0,
#   97,
#   0,
#   70,
#   'E',
#   18),
#  (Timestamp('2024-08-30 02:00:00'),
#   'id28005',
#   'Poco nuboso',
#   18,
#   18,
#   29.0,
#   0.0,
#   0,
#   100,
#   0,
#   15,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 03:00:00'),
#   'id28005',
#   'Nuboso',
#   18,
#   18,
#   24.0,
#   0.0,
#   0,
#   100,
#   0,
#   15,
#   'N',
#   19),
#  (Timestamp('2024-08-30 04:00:00'),
#   'id28005',
#   'Muy nuboso',
#   18,
#   18,
#   18.0,
#   0.0,
#   0,
#   100,
#   0,
#   15,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 05:00:00'),
#   'id28005',
#   'Cielo despejado',
#   18,
#   18,
#   19.0,
#   0.0,
#   0,
#   100,
#   0,
#   15,
#   'NE',
#   12),
#  (Timestamp('2024-08-30 06:00:00'),
#   'id28005',
#   'Nuboso',
#   18,
#   18,
#   21.0,
#   0.0,
#   0,
#   100,
#   0,
#   15,
#   'NE',
#   13),
#  (Timestamp('2024-08-30 07:00:00'),
#   'id28005',
#   'Poco nuboso',
#   18,
#   18,
#   15.0,
#   0.0,
#   0,
#   100,
#   0,
#   15,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 08:00:00'),
#   'id28005',
#   'Cubierto',
#   17,
#   17,
#   23.0,
#   0.0,
#   0,
#   100,
#   0,
#   25,
#   'NE',
#   9),
#  (Timestamp('2024-08-30 09:00:00'),
#   'id28005',
#   'Muy nuboso',
#   20,
#   20,
#   16.0,
#   0.0,
#   0,
#   94,
#   0,
#   25,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 10:00:00'),
#   'id28005',
#   'Cubierto',
#   22,
#   22,
#   30.0,
#   0.0,
#   0,
#   85,
#   0,
#   25,
#   'NE',
#   8),
#  (Timestamp('2024-08-30 11:00:00'),
#   'id28005',
#   'Muy nuboso',
#   24,
#   24,
#   35.0,
#   0.0,
#   0,
#   77,
#   0,
#   25,
#   'SE',
#   20),
#  (Timestamp('2024-08-30 12:00:00'),
#   'id28005',
#   'Nubes altas',
#   26,
#   26,
#   34.0,
#   0.0,
#   0,
#   58,
#   0,
#   25,
#   'E',
#   23),
#  (Timestamp('2024-08-30 13:00:00'),
#   'id28005',
#   'Nubes altas',
#   27,
#   28,
#   31.0,
#   0.0,
#   0,
#   56,
#   0,
#   25,
#   'NO',
#   22),
#  (Timestamp('2024-08-30 14:00:00'),
#   'id28005',
#   'Muy nuboso',
#   28,
#   29,
#   25.0,
#   0.0,
#   0,
#   51,
#   0,
#   60,
#   'N',
#   15),
#  (Timestamp('2024-08-30 15:00:00'),
#   'id28005',
#   'Cubierto',
#   29,
#   30,
#   19.0,
#   0.0,
#   0,
#   56,
#   0,
#   60,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 16:00:00'),
#   'id28005',
#   'Intervalos nubosos con lluvia escasa',
#   30,
#   31,
#   20.0,
#   0.1,
#   0,
#   50,
#   0,
#   60,
#   'NE',
#   10),
#  (Timestamp('2024-08-30 17:00:00'),
#   'id28005',
#   'Cubierto',
#   31,
#   33,
#   14.0,
#   0.0,
#   0,
#   52,
#   0,
#   60,
#   'NE',
#   10),
#  (Timestamp('2024-08-30 18:00:00'),
#   'id28005',
#   'Poco nuboso',
#   28,
#   29,
#   16.0,
#   0.0,
#   0,
#   52,
#   0,
#   60,
#   'E',
#   7),
#  (Timestamp('2024-08-30 19:00:00'),
#   'id28005',
#   'Cielo despejado',
#   26,
#   26,
#   17.0,
#   0.0,
#   0,
#   60,
#   0,
#   60,
#   'NE',
#   9),
#  (Timestamp('2024-08-30 20:00:00'),
#   'id28005',
#   'Poco nuboso',
#   24,
#   24,
#   9.0,
#   0.0,
#   0,
#   75,
#   0,
#   25,
#   'NE',
#   9),
#  (Timestamp('2024-08-30 21:00:00'),
#   'id28005',
#   'Poco nuboso',
#   23,
#   23,
#   12.0,
#   0.0,
#   0,
#   85,
#   0,
#   25,
#   'NE',
#   6),
#  (Timestamp('2024-08-30 22:00:00'),
#   'id28005',
#   'Poco nuboso',
#   22,
#   22,
#   14.0,
#   0.0,
#   0,
#   90,
#   0,
#   25,
#   'NE',
#   8),
#  (Timestamp('2024-08-30 23:00:00'),
#   'id28005',
#   'Cubierto',
#   21,
#   21,
#   15.0,
#   0.0,
#   0,
#   91,
#   0,
#   25,
#   'E',
#   10),
#  (Timestamp('2024-08-31 00:00:00'),
#   'id28005',
#   'Muy nuboso',
#   21,
#   21,
#   10.0,
#   0.0,
#   0,
#   85,
#   0,
#   25,
#   'N',
#   8),
#  (Timestamp('2024-08-31 01:00:00'),
#   'id28005',
#   'Muy nuboso',
#   20,
#   20,
#   9.0,
#   0.0,
#   0,
#   83,
#   0,
#   25,
#   'N',
#   6),
#  (Timestamp('2024-08-31 02:00:00'),
#   'id28005',
#   'Nuboso',
#   19,
#   19,
#   11.0,
#   0.0,
#   0,
#   85,
#   0,
#   10,
#   'NE',
#   3),
#  (Timestamp('2024-08-31 03:00:00'),
#   'id28005',
#   'Poco nuboso',
#   19,
#   19,
#   14.0,
#   0.0,
#   0,
#   92,
#   0,
#   10,
#   'O',
#   2),
#  (Timestamp('2024-08-31 04:00:00'),
#   'id28005',
#   'Cielo despejado',
#   18,
#   18,
#   13.0,
#   0.0,
#   0,
#   91,
#   0,
#   10,
#   'NE',
#   8),
#  (Timestamp('2024-08-31 05:00:00'),
#   'id28005',
#   'Cielo despejado',
#   17,
#   17,
#   12.0,
#   0.0,
#   0,
#   99,
#   0,
#   10,
#   'NE',
#   9),
#  (Timestamp('2024-08-31 06:00:00'),
#   'id28005',
#   'Poco nuboso',
#   17,
#   17,
#   10.0,
#   0.0,
#   0,
#   96,
#   0,
#   10,
#   'E',
#   5),
#  (Timestamp('2024-08-31 07:00:00'),
#   'id28005',
#   'Nuboso',
#   17,
#   17,
#   10.0,
#   0.0,
#   0,
#   93,
#   0,
#   10,
#   'E',
#   7),
#  (Timestamp('2024-08-29 12:00:00'),
#   'id28006',
#   'Cubierto con lluvia escasa',
#   23,
#   23,
#   16.0,
#   0.1,
#   0,
#   65,
#   0,
#   70,
#   'E',
#   9),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28006',
#   'Cubierto con lluvia escasa',
#   25,
#   25,
#   19.0,
#   0.1,
#   0,
#   59,
#   0,
#   70,
#   'NE',
#   8),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28006',
#   'Muy nuboso',
#   27,
#   28,
#   21.0,
#   0.0,
#   0,
#   52,
#   0,
#   75,
#   'E',
#   7),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28006',
#   'Nubes altas',
#   27,
#   27,
#   13.0,
#   0.0,
#   0,
#   49,
#   0,
#   75,
#   'S',
#   10),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28006',
#   'Cubierto con tormenta y lluvia escasa',
#   28,
#   28,
#   50.0,
#   1.0,
#   0,
#   43,
#   0,
#   75,
#   'SO',
#   5),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28006',
#   'Cubierto con tormenta y lluvia escasa',
#   27,
#   28,
#   9.0,
#   1.0,
#   0,
#   61,
#   0,
#   75,
#   'S',
#   31),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28006',
#   'Nubes altas',
#   25,
#   25,
#   61.0,
#   0.0,
#   0,
#   65,
#   0,
#   75,
#   'NO',
#   4),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28006',
#   'Nuboso',
#   24,
#   24,
#   24.0,
#   0.0,
#   0,
#   51,
#   0,
#   75,
#   'NO',
#   24),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28006',
#   'Cubierto',
#   22,
#   22,
#   19.0,
#   0.0,
#   0,
#   62,
#   0,
#   65,
#   'NO',
#   15),
#  (Timestamp('2024-08-29 21:00:00'),
#   'id28006',
#   'Nubes altas',
#   21,
#   21,
#   21.0,
#   0.0,
#   0,
#   68,
#   0,
#   65,
#   'N',
#   12),
#  (Timestamp('2024-08-29 22:00:00'),
#   'id28006',
#   'Cielo despejado',
#   21,
#   21,
#   22.0,
#   0.0,
#   0,
#   82,
#   0,
#   65,
#   'NE',
#   12),
#  (Timestamp('2024-08-29 23:00:00'),
#   'id28006',
#   'Muy nuboso con lluvia escasa',
#   21,
#   21,
#   23.0,
#   0.1,
#   0,
#   82,
#   0,
#   65,
#   'N',
#   14),
#  (Timestamp('2024-08-30 00:00:00'),
#   'id28006',
#   'Cubierto',
#   20,
#   20,
#   16.0,
#   0.0,
#   0,
#   86,
#   0,
#   65,
#   'N',
#   14),
#  (Timestamp('2024-08-30 01:00:00'),
#   'id28006',
#   'Intervalos nubosos con lluvia escasa',
#   20,
#   20,
#   24.0,
#   0.1,
#   0,
#   89,
#   0,
#   65,
#   'N',
#   10),
#  (Timestamp('2024-08-30 02:00:00'),
#   'id28006',
#   'Poco nuboso',
#   19,
#   19,
#   34.0,
#   0.0,
#   0,
#   88,
#   0,
#   20,
#   'N',
#   15),
#  (Timestamp('2024-08-30 03:00:00'),
#   'id28006',
#   'Muy nuboso',
#   19,
#   19,
#   27.0,
#   0.0,
#   0,
#   87,
#   0,
#   20,
#   'N',
#   18),
#  (Timestamp('2024-08-30 04:00:00'),
#   'id28006',
#   'Cubierto',
#   19,
#   19,
#   23.0,
#   0.0,
#   0,
#   89,
#   0,
#   20,
#   'NE',
#   17),
#  (Timestamp('2024-08-30 05:00:00'),
#   'id28006',
#   'Nuboso',
#   19,
#   19,
#   24.0,
#   0.0,
#   0,
#   89,
#   0,
#   20,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 06:00:00'),
#   'id28006',
#   'Cielo despejado',
#   19,
#   19,
#   25.0,
#   0.0,
#   0,
#   90,
#   0,
#   20,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 07:00:00'),
#   'id28006',
#   'Cielo despejado',
#   18,
#   18,
#   19.0,
#   0.0,
#   0,
#   95,
#   0,
#   20,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 08:00:00'),
#   'id28006',
#   'Cubierto',
#   18,
#   18,
#   23.0,
#   0.0,
#   0,
#   99,
#   0,
#   20,
#   'N',
#   11),
#  (Timestamp('2024-08-30 09:00:00'),
#   'id28006',
#   'Cubierto',
#   20,
#   20,
#   17.0,
#   0.0,
#   0,
#   89,
#   0,
#   20,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 10:00:00'),
#   'id28006',
#   'Cubierto',
#   22,
#   22,
#   34.0,
#   0.0,
#   0,
#   83,
#   0,
#   20,
#   'E',
#   10),
#  (Timestamp('2024-08-30 11:00:00'),
#   'id28006',
#   'Cubierto',
#   24,
#   24,
#   14.0,
#   0.0,
#   0,
#   75,
#   0,
#   20,
#   'SE',
#   21),
#  (Timestamp('2024-08-30 12:00:00'),
#   'id28006',
#   'Cubierto',
#   25,
#   25,
#   30.0,
#   0.0,
#   0,
#   67,
#   0,
#   20,
#   'S',
#   3),
#  (Timestamp('2024-08-30 13:00:00'),
#   'id28006',
#   'Nubes altas',
#   26,
#   26,
#   31.0,
#   0.0,
#   0,
#   56,
#   0,
#   20,
#   'C',
#   0),
#  (Timestamp('2024-08-30 14:00:00'),
#   'id28006',
#   'Cubierto',
#   28,
#   29,
#   25.0,
#   0.0,
#   0,
#   52,
#   0,
#   50,
#   'NE',
#   17),
#  (Timestamp('2024-08-30 15:00:00'),
#   'id28006',
#   'Poco nuboso',
#   29,
#   29,
#   21.0,
#   0.0,
#   0,
#   47,
#   0,
#   50,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 16:00:00'),
#   'id28006',
#   'Poco nuboso',
#   29,
#   29,
#   23.0,
#   0.0,
#   0,
#   45,
#   0,
#   50,
#   'NE',
#   11),
#  (Timestamp('2024-08-30 17:00:00'),
#   'id28006',
#   'Intervalos nubosos con lluvia escasa',
#   30,
#   30,
#   22.0,
#   0.1,
#   0,
#   45,
#   0,
#   50,
#   'NE',
#   11),
#  (Timestamp('2024-08-30 18:00:00'),
#   'id28006',
#   'Cielo despejado',
#   27,
#   28,
#   22.0,
#   0.0,
#   0,
#   59,
#   0,
#   50,
#   'NE',
#   12),
#  (Timestamp('2024-08-30 19:00:00'),
#   'id28006',
#   'Poco nuboso',
#   23,
#   23,
#   20.0,
#   0.0,
#   0,
#   79,
#   0,
#   50,
#   'NE',
#   13),
#  (Timestamp('2024-08-30 20:00:00'),
#   'id28006',
#   'Poco nuboso',
#   24,
#   24,
#   12.0,
#   0.0,
#   0,
#   76,
#   0,
#   25,
#   'NE',
#   11),
#  (Timestamp('2024-08-30 21:00:00'),
#   'id28006',
#   'Nubes altas',
#   23,
#   23,
#   17.0,
#   0.0,
#   0,
#   73,
#   0,
#   25,
#   'NE',
#   7),
#  (Timestamp('2024-08-30 22:00:00'),
#   'id28006',
#   'Nubes altas',
#   23,
#   23,
#   17.0,
#   0.0,
#   0,
#   79,
#   0,
#   25,
#   'N',
#   11),
#  (Timestamp('2024-08-30 23:00:00'),
#   'id28006',
#   'Muy nuboso',
#   22,
#   22,
#   10.0,
#   0.0,
#   0,
#   87,
#   0,
#   25,
#   'N',
#   11),
#  (Timestamp('2024-08-31 00:00:00'),
#   'id28006',
#   'Poco nuboso',
#   21,
#   21,
#   10.0,
#   0.0,
#   0,
#   85,
#   0,
#   25,
#   'E',
#   6),
#  (Timestamp('2024-08-31 01:00:00'),
#   'id28006',
#   'Cubierto',
#   21,
#   21,
#   12.0,
#   0.0,
#   0,
#   83,
#   0,
#   25,
#   'NE',
#   7),
#  (Timestamp('2024-08-31 02:00:00'),
#   'id28006',
#   'Muy nuboso',
#   20,
#   20,
#   13.0,
#   0.0,
#   0,
#   86,
#   0,
#   0,
#   'NE',
#   8),
#  (Timestamp('2024-08-31 03:00:00'),
#   'id28006',
#   'Cubierto',
#   20,
#   20,
#   10.0,
#   0.0,
#   0,
#   87,
#   0,
#   0,
#   'E',
#   8),
#  (Timestamp('2024-08-31 04:00:00'),
#   'id28006',
#   'Cielo despejado',
#   19,
#   19,
#   15.0,
#   0.0,
#   0,
#   78,
#   0,
#   0,
#   'E',
#   5),
#  (Timestamp('2024-08-31 05:00:00'),
#   'id28006',
#   'Muy nuboso',
#   19,
#   19,
#   20.0,
#   0.0,
#   0,
#   86,
#   0,
#   0,
#   'N',
#   10),
#  (Timestamp('2024-08-31 06:00:00'),
#   'id28006',
#   'Cielo despejado',
#   19,
#   19,
#   11.0,
#   0.0,
#   0,
#   90,
#   0,
#   0,
#   'N',
#   10),
#  (Timestamp('2024-08-31 07:00:00'),
#   'id28006',
#   'Nubes altas',
#   18,
#   18,
#   5.0,
#   0.0,
#   0,
#   91,
#   0,
#   0,
#   'NE',
#   7),
#  (Timestamp('2024-08-29 11:00:00'),
#   'id28007',
#   'Cubierto con lluvia escasa',
#   23,
#   23,
#   19.0,
#   0.1,
#   0,
#   68,
#   0,
#   65,
#   'E',
#   10),
#  (Timestamp('2024-08-29 12:00:00'),
#   'id28007',
#   'Intervalos nubosos con lluvia escasa',
#   24,
#   24,
#   19.0,
#   0.1,
#   0,
#   60,
#   0,
#   65,
#   'E',
#   9),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28007',
#   'Nuboso con lluvia escasa',
#   25,
#   25,
#   18.0,
#   0.1,
#   0,
#   55,
#   0,
#   65,
#   'E',
#   8),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28007',
#   'Nubes altas',
#   26,
#   26,
#   21.0,
#   0.0,
#   0,
#   49,
#   0,
#   70,
#   'SE',
#   8),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28007',
#   'Cubierto',
#   27,
#   27,
#   18.0,
#   0.0,
#   0,
#   46,
#   0,
#   70,
#   'SE',
#   10),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28007',
#   'Cubierto',
#   27,
#   27,
#   46.0,
#   0.0,
#   0,
#   44,
#   0,
#   70,
#   'SE',
#   7),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28007',
#   'Cubierto',
#   28,
#   28,
#   15.0,
#   0.0,
#   0,
#   47,
#   0,
#   70,
#   'SE',
#   22),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28007',
#   'Intervalos nubosos con lluvia escasa',
#   25,
#   25,
#   19.0,
#   0.8,
#   0,
#   52,
#   0,
#   70,
#   'C',
#   0),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28007',
#   'Nuboso',
#   22,
#   22,
#   21.0,
#   0.0,
#   0,
#   72,
#   0,
#   70,
#   'NE',
#   12),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28007',
#   'Intervalos nubosos con lluvia escasa',
#   20,
#   20,
#   17.0,
#   0.1,
#   0,
#   81,
#   0,
#   70,
#   'N',
#   11),
#  (Timestamp('2024-08-29 21:00:00'),
#   'id28007',
#   'Cubierto con lluvia escasa',
#   20,
#   20,
#   25.0,
#   0.1,
#   0,
#   77,
#   0,
#   70,
#   'E',
#   11),
#  (Timestamp('2024-08-29 22:00:00'),
#   'id28007',
#   'Cubierto con lluvia escasa',
#   18,
#   18,
#   28.0,
#   0.1,
#   0,
#   78,
#   0,
#   70,
#   'NE',
#   15),
#  (Timestamp('2024-08-29 23:00:00'),
#   'id28007',
#   'Nuboso con lluvia escasa',
#   19,
#   19,
#   23.0,
#   0.1,
#   0,
#   81,
#   0,
#   70,
#   'NE',
#   18),
#  (Timestamp('2024-08-30 00:00:00'),
#   'id28007',
#   'Intervalos nubosos con lluvia escasa',
#   18,
#   18,
#   28.0,
#   0.1,
#   0,
#   86,
#   0,
#   70,
#   'NE',
#   13),
#  (Timestamp('2024-08-30 01:00:00'),
#   'id28007',
#   'Intervalos nubosos con lluvia escasa',
#   18,
#   18,
#   30.0,
#   0.1,
#   0,
#   91,
#   0,
#   70,
#   'NE',
#   17),
#  (Timestamp('2024-08-30 02:00:00'),
#   'id28007',
#   'Muy nuboso',
#   18,
#   18,
#   36.0,
#   0.0,
#   0,
#   95,
#   0,
#   15,
#   'NE',
#   19),
#  (Timestamp('2024-08-30 03:00:00'),
#   'id28007',
#   'Muy nuboso',
#   18,
#   18,
#   30.0,
#   0.0,
#   0,
#   90,
#   0,
#   15,
#   'NE',
#   22),
#  (Timestamp('2024-08-30 04:00:00'),
#   'id28007',
#   'Nuboso',
#   18,
#   18,
#   30.0,
#   0.0,
#   0,
#   89,
#   0,
#   15,
#   'NE',
#   19),
#  (Timestamp('2024-08-30 05:00:00'),
#   'id28007',
#   'Poco nuboso',
#   18,
#   18,
#   27.0,
#   0.0,
#   0,
#   87,
#   0,
#   15,
#   'NE',
#   18),
#  (Timestamp('2024-08-30 06:00:00'),
#   'id28007',
#   'Cielo despejado',
#   18,
#   18,
#   26.0,
#   0.0,
#   0,
#   91,
#   0,
#   15,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 07:00:00'),
#   'id28007',
#   'Poco nuboso',
#   17,
#   17,
#   26.0,
#   0.0,
#   0,
#   94,
#   0,
#   15,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 08:00:00'),
#   'id28007',
#   'Poco nuboso',
#   17,
#   17,
#   26.0,
#   0.0,
#   0,
#   100,
#   0,
#   20,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 09:00:00'),
#   'id28007',
#   'Cubierto',
#   19,
#   19,
#   26.0,
#   0.0,
#   0,
#   90,
#   0,
#   20,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 10:00:00'),
#   'id28007',
#   'Cubierto',
#   21,
#   21,
#   32.0,
#   0.0,
#   0,
#   80,
#   0,
#   20,
#   'E',
#   16),
#  (Timestamp('2024-08-30 11:00:00'),
#   'id28007',
#   'Cubierto',
#   23,
#   23,
#   39.0,
#   0.0,
#   0,
#   77,
#   0,
#   20,
#   'E',
#   16),
#  (Timestamp('2024-08-30 12:00:00'),
#   'id28007',
#   'Cubierto',
#   25,
#   25,
#   40.0,
#   0.0,
#   0,
#   68,
#   0,
#   20,
#   'E',
#   25),
#  (Timestamp('2024-08-30 13:00:00'),
#   'id28007',
#   'Nubes altas',
#   26,
#   26,
#   32.0,
#   0.0,
#   0,
#   60,
#   0,
#   20,
#   'N',
#   18),
#  (Timestamp('2024-08-30 14:00:00'),
#   'id28007',
#   'Muy nuboso con lluvia escasa',
#   27,
#   28,
#   33.0,
#   0.1,
#   0,
#   54,
#   0,
#   55,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 15:00:00'),
#   'id28007',
#   'Muy nuboso con lluvia escasa',
#   28,
#   29,
#   30.0,
#   0.1,
#   0,
#   52,
#   0,
#   55,
#   'NE',
#   18),
#  (Timestamp('2024-08-30 16:00:00'),
#   'id28007',
#   'Intervalos nubosos con lluvia escasa',
#   28,
#   28,
#   28.0,
#   0.1,
#   0,
#   44,
#   0,
#   55,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 17:00:00'),
#   'id28007',
#   'Intervalos nubosos con lluvia escasa',
#   29,
#   29,
#   27.0,
#   0.1,
#   0,
#   43,
#   0,
#   55,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 18:00:00'),
#   'id28007',
#   'Intervalos nubosos con lluvia escasa',
#   27,
#   27,
#   25.0,
#   0.1,
#   0,
#   49,
#   0,
#   55,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 19:00:00'),
#   'id28007',
#   'Intervalos nubosos con lluvia escasa',
#   25,
#   25,
#   21.0,
#   0.1,
#   0,
#   61,
#   0,
#   55,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 20:00:00'),
#   'id28007',
#   'Poco nuboso',
#   23,
#   23,
#   18.0,
#   0.0,
#   0,
#   74,
#   0,
#   20,
#   'NE',
#   12),
#  (Timestamp('2024-08-30 21:00:00'),
#   'id28007',
#   'Nubes altas',
#   22,
#   22,
#   23.0,
#   0.0,
#   0,
#   75,
#   0,
#   20,
#   'E',
#   10),
#  (Timestamp('2024-08-30 22:00:00'),
#   'id28007',
#   'Nubes altas',
#   21,
#   21,
#   20.0,
#   0.0,
#   0,
#   80,
#   0,
#   20,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 23:00:00'),
#   'id28007',
#   'Cielo despejado',
#   20,
#   20,
#   18.0,
#   0.0,
#   0,
#   89,
#   0,
#   20,
#   'NE',
#   12),
#  (Timestamp('2024-08-31 00:00:00'),
#   'id28007',
#   'Poco nuboso',
#   20,
#   20,
#   17.0,
#   0.0,
#   0,
#   95,
#   0,
#   20,
#   'E',
#   11),
#  (Timestamp('2024-08-31 01:00:00'),
#   'id28007',
#   'Cubierto',
#   20,
#   20,
#   16.0,
#   0.0,
#   0,
#   91,
#   0,
#   20,
#   'E',
#   11),
#  (Timestamp('2024-08-31 02:00:00'),
#   'id28007',
#   'Muy nuboso',
#   19,
#   19,
#   24.0,
#   0.0,
#   0,
#   89,
#   0,
#   5,
#   'NE',
#   10),
#  (Timestamp('2024-08-31 03:00:00'),
#   'id28007',
#   'Cubierto',
#   19,
#   19,
#   17.0,
#   0.0,
#   0,
#   83,
#   0,
#   5,
#   'E',
#   15),
#  (Timestamp('2024-08-31 04:00:00'),
#   'id28007',
#   'Poco nuboso',
#   19,
#   19,
#   23.0,
#   0.0,
#   0,
#   80,
#   0,
#   5,
#   'NE',
#   9),
#  (Timestamp('2024-08-31 05:00:00'),
#   'id28007',
#   'Nuboso',
#   18,
#   18,
#   17.0,
#   0.0,
#   0,
#   83,
#   0,
#   5,
#   'NE',
#   14),
#  (Timestamp('2024-08-31 06:00:00'),
#   'id28007',
#   'Cielo despejado',
#   18,
#   18,
#   12.0,
#   0.0,
#   0,
#   85,
#   0,
#   5,
#   'NE',
#   9),
#  (Timestamp('2024-08-31 07:00:00'),
#   'id28007',
#   'Nubes altas',
#   18,
#   18,
#   11.0,
#   0.0,
#   0,
#   90,
#   0,
#   5,
#   'NE',
#   7),
#  (Timestamp('2024-08-29 12:00:00'),
#   'id28008',
#   'Muy nuboso con lluvia escasa',
#   26,
#   26,
#   16.0,
#   0.1,
#   0,
#   51,
#   0,
#   60,
#   'E',
#   9),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28008',
#   'Intervalos nubosos con lluvia escasa',
#   27,
#   27,
#   18.0,
#   0.1,
#   0,
#   46,
#   0,
#   60,
#   'E',
#   6),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28008',
#   'Cubierto',
#   29,
#   29,
#   21.0,
#   0.0,
#   0,
#   40,
#   0,
#   65,
#   'SE',
#   7),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28008',
#   'Cubierto',
#   30,
#   30,
#   21.0,
#   0.0,
#   0,
#   36,
#   0,
#   65,
#   'SE',
#   8),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28008',
#   'Muy nuboso',
#   31,
#   31,
#   20.0,
#   0.0,
#   0,
#   34,
#   0,
#   65,
#   'SE',
#   8),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28008',
#   'Muy nuboso con lluvia escasa',
#   30,
#   30,
#   21.0,
#   0.7,
#   0,
#   36,
#   0,
#   65,
#   'SO',
#   10),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28008',
#   'Cubierto con lluvia escasa',
#   28,
#   29,
#   33.0,
#   0.5,
#   0,
#   57,
#   0,
#   65,
#   'NE',
#   12),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28008',
#   'Muy nuboso',
#   26,
#   26,
#   19.0,
#   0.0,
#   0,
#   60,
#   0,
#   65,
#   'NE',
#   20),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28008',
#   'Nubes altas',
#   24,
#   24,
#   16.0,
#   0.0,
#   0,
#   60,
#   0,
#   40,
#   'N',
#   9),
#  (Timestamp('2024-08-29 21:00:00'),
#   'id28008',
#   'Poco nuboso',
#   22,
#   22,
#   20.0,
#   0.0,
#   0,
#   70,
#   0,
#   40,
#   'SO',
#   10),
#  (Timestamp('2024-08-29 22:00:00'),
#   'id28008',
#   'Poco nuboso',
#   20,
#   20,
#   19.0,
#   0.0,
#   0,
#   78,
#   0,
#   40,
#   'E',
#   12),
#  (Timestamp('2024-08-29 23:00:00'),
#   'id28008',
#   'Poco nuboso',
#   20,
#   20,
#   18.0,
#   0.0,
#   0,
#   80,
#   0,
#   40,
#   'NE',
#   11),
#  (Timestamp('2024-08-30 00:00:00'),
#   'id28008',
#   'Muy nuboso',
#   20,
#   20,
#   11.0,
#   0.0,
#   0,
#   81,
#   0,
#   40,
#   'N',
#   11),
#  (Timestamp('2024-08-30 01:00:00'),
#   'id28008',
#   'Poco nuboso',
#   19,
#   19,
#   11.0,
#   0.0,
#   0,
#   79,
#   0,
#   40,
#   'NE',
#   6),
#  (Timestamp('2024-08-30 02:00:00'),
#   'id28008',
#   'Poco nuboso',
#   19,
#   19,
#   12.0,
#   0.0,
#   0,
#   82,
#   0,
#   5,
#   'NE',
#   7),
#  (Timestamp('2024-08-30 03:00:00'),
#   'id28008',
#   'Nuboso',
#   19,
#   19,
#   20.0,
#   0.0,
#   0,
#   80,
#   0,
#   5,
#   'N',
#   7),
#  (Timestamp('2024-08-30 04:00:00'),
#   'id28008',
#   'Nuboso',
#   19,
#   19,
#   21.0,
#   0.0,
#   0,
#   85,
#   0,
#   5,
#   'NE',
#   12),
#  (Timestamp('2024-08-30 05:00:00'),
#   'id28008',
#   'Poco nuboso',
#   18,
#   18,
#   18.0,
#   0.0,
#   0,
#   86,
#   0,
#   5,
#   'NE',
#   13),
#  (Timestamp('2024-08-30 06:00:00'),
#   'id28008',
#   'Cielo despejado',
#   18,
#   18,
#   23.0,
#   0.0,
#   0,
#   91,
#   0,
#   5,
#   'NE',
#   10),
#  (Timestamp('2024-08-30 07:00:00'),
#   'id28008',
#   'Cubierto',
#   18,
#   18,
#   24.0,
#   0.0,
#   0,
#   94,
#   0,
#   5,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 08:00:00'),
#   'id28008',
#   'Poco nuboso',
#   18,
#   18,
#   28.0,
#   0.0,
#   0,
#   97,
#   0,
#   15,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 09:00:00'),
#   'id28008',
#   'Nuboso',
#   21,
#   21,
#   29.0,
#   0.0,
#   0,
#   85,
#   0,
#   15,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 10:00:00'),
#   'id28008',
#   'Cubierto',
#   23,
#   23,
#   30.0,
#   0.0,
#   0,
#   77,
#   0,
#   15,
#   'NE',
#   17),
#  (Timestamp('2024-08-30 11:00:00'),
#   'id28008',
#   'Cubierto',
#   25,
#   25,
#   25.0,
#   0.0,
#   0,
#   67,
#   0,
#   15,
#   'NE',
#   18),
#  (Timestamp('2024-08-30 12:00:00'),
#   'id28008',
#   'Intervalos nubosos',
#   27,
#   29,
#   36.0,
#   0.0,
#   0,
#   70,
#   0,
#   15,
#   'E',
#   15),
#  (Timestamp('2024-08-30 13:00:00'),
#   'id28008',
#   'Nubes altas',
#   28,
#   29,
#   24.0,
#   0.0,
#   0,
#   57,
#   0,
#   15,
#   'NE',
#   22),
#  (Timestamp('2024-08-30 14:00:00'),
#   'id28008',
#   'Nubes altas',
#   30,
#   31,
#   35.0,
#   0.0,
#   0,
#   48,
#   0,
#   45,
#   'E',
#   12),
#  (Timestamp('2024-08-30 15:00:00'),
#   'id28008',
#   'Cubierto',
#   31,
#   32,
#   33.0,
#   0.0,
#   0,
#   44,
#   0,
#   45,
#   'NE',
#   19),
#  (Timestamp('2024-08-30 16:00:00'),
#   'id28008',
#   'Nubes altas',
#   31,
#   31,
#   28.0,
#   0.0,
#   0,
#   40,
#   0,
#   45,
#   'NE',
#   17),
#  (Timestamp('2024-08-30 17:00:00'),
#   'id28008',
#   'Poco nuboso',
#   32,
#   32,
#   29.0,
#   0.0,
#   0,
#   40,
#   0,
#   45,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 18:00:00'),
#   'id28008',
#   'Nubes altas',
#   31,
#   31,
#   26.0,
#   0.0,
#   0,
#   41,
#   0,
#   45,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 19:00:00'),
#   'id28008',
#   'Poco nuboso',
#   29,
#   29,
#   21.0,
#   0.0,
#   0,
#   45,
#   0,
#   45,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 20:00:00'),
#   'id28008',
#   'Muy nuboso',
#   28,
#   28,
#   18.0,
#   0.0,
#   0,
#   50,
#   0,
#   15,
#   'NE',
#   13),
#  (Timestamp('2024-08-30 21:00:00'),
#   'id28008',
#   'Nubes altas',
#   26,
#   26,
#   23.0,
#   0.0,
#   0,
#   61,
#   0,
#   15,
#   'NE',
#   11),
#  (Timestamp('2024-08-30 22:00:00'),
#   'id28008',
#   'Nubes altas',
#   23,
#   23,
#   16.0,
#   0.0,
#   0,
#   71,
#   0,
#   15,
#   'NE',
#   13),
#  (Timestamp('2024-08-30 23:00:00'),
#   'id28008',
#   'Poco nuboso',
#   21,
#   21,
#   16.0,
#   0.0,
#   0,
#   77,
#   0,
#   15,
#   'N',
#   10),
#  (Timestamp('2024-08-31 00:00:00'),
#   'id28008',
#   'Cielo despejado',
#   21,
#   21,
#   23.0,
#   0.0,
#   0,
#   81,
#   0,
#   15,
#   'NE',
#   10),
#  (Timestamp('2024-08-31 01:00:00'),
#   'id28008',
#   'Muy nuboso',
#   20,
#   20,
#   24.0,
#   0.0,
#   0,
#   82,
#   0,
#   15,
#   'NE',
#   14),
#  (Timestamp('2024-08-31 02:00:00'),
#   'id28008',
#   'Nuboso',
#   21,
#   21,
#   22.0,
#   0.0,
#   0,
#   83,
#   0,
#   5,
#   'NE',
#   15),
#  (Timestamp('2024-08-31 03:00:00'),
#   'id28008',
#   'Nuboso',
#   20,
#   20,
#   23.0,
#   0.0,
#   0,
#   84,
#   0,
#   5,
#   'NE',
#   12),
#  (Timestamp('2024-08-31 04:00:00'),
#   'id28008',
#   'Poco nuboso',
#   20,
#   20,
#   14.0,
#   0.0,
#   0,
#   86,
#   0,
#   5,
#   'NE',
#   14),
#  (Timestamp('2024-08-31 05:00:00'),
#   'id28008',
#   'Cielo despejado',
#   19,
#   19,
#   12.0,
#   0.0,
#   0,
#   84,
#   0,
#   5,
#   'N',
#   7),
#  (Timestamp('2024-08-31 06:00:00'),
#   'id28008',
#   'Poco nuboso',
#   19,
#   19,
#   9.0,
#   0.0,
#   0,
#   82,
#   0,
#   5,
#   'N',
#   7),
#  (Timestamp('2024-08-31 07:00:00'),
#   'id28008',
#   'Nubes altas',
#   19,
#   19,
#   9.0,
#   0.0,
#   0,
#   83,
#   0,
#   5,
#   'N',
#   5),
#  (Timestamp('2024-08-29 11:00:00'),
#   'id28009',
#   'Cubierto con tormenta y lluvia escasa',
#   22,
#   22,
#   16.0,
#   0.1,
#   0,
#   75,
#   0,
#   70,
#   'E',
#   8),
#  (Timestamp('2024-08-29 12:00:00'),
#   'id28009',
#   'Cubierto con tormenta y lluvia escasa',
#   24,
#   24,
#   15.0,
#   0.1,
#   0,
#   67,
#   0,
#   70,
#   'E',
#   8),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28009',
#   'Cubierto con tormenta y lluvia escasa',
#   25,
#   25,
#   19.0,
#   0.1,
#   0,
#   59,
#   0,
#   70,
#   'E',
#   7),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28009',
#   'Nubes altas',
#   27,
#   28,
#   19.0,
#   0.0,
#   0,
#   53,
#   0,
#   75,
#   'SE',
#   8),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28009',
#   'Nubes altas',
#   28,
#   28,
#   20.0,
#   0.0,
#   0,
#   46,
#   0,
#   75,
#   'S',
#   8),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28009',
#   'Cubierto',
#   26,
#   26,
#   41.0,
#   0.0,
#   0,
#   47,
#   0,
#   75,
#   'SO',
#   11),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28009',
#   'Cubierto con tormenta y lluvia escasa',
#   24,
#   24,
#   10.0,
#   0.1,
#   0,
#   51,
#   0,
#   75,
#   'S',
#   26),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28009',
#   'Cubierto',
#   25,
#   25,
#   58.0,
#   0.0,
#   0,
#   56,
#   0,
#   75,
#   'O',
#   5),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28009',
#   'Poco nuboso',
#   23,
#   23,
#   17.0,
#   0.0,
#   0,
#   52,
#   0,
#   75,
#   'O',
#   34),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28009',
#   'Cubierto',
#   21,
#   21,
#   23.0,
#   0.0,
#   0,
#   51,
#   0,
#   65,
# ...
#   'id28021',
#   'Nuboso',
#   17,
#   17,
#   11.0,
#   0.0,
#   0,
#   90,
#   0,
#   5,
#   'NE',
#   5),
#  (Timestamp('2024-08-31 05:00:00'),
#   'id28021',
#   'Poco nuboso',
#   16,
#   16,
#   19.0,
#   0.0,
#   0,
#   92,
#   0,
#   5,
#   'N',
#   4),
#  (Timestamp('2024-08-31 06:00:00'),
#   'id28021',
#   'Cielo despejado',
#   16,
#   16,
#   27.0,
#   0.0,
#   0,
#   91,
#   0,
#   5,
#   'N',
#   10),
#  (Timestamp('2024-08-31 07:00:00'),
#   'id28021',
#   'Nubes altas',
#   15,
#   15,
#   24.0,
#   0.0,
#   0,
#   94,
#   0,
#   5,
#   'N',
#   13),
#  (Timestamp('2024-08-29 12:00:00'),
#   'id28020',
#   'Cubierto',
#   22,
#   22,
#   22.0,
#   0.0,
#   0,
#   76,
#   0,
#   75,
#   'S',
#   8),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28020',
#   'Nubes altas',
#   23,
#   23,
#   24.0,
#   0.0,
#   0,
#   66,
#   0,
#   75,
#   'S',
#   11),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28020',
#   'Nubes altas',
#   25,
#   25,
#   28.0,
#   0.0,
#   0,
#   58,
#   0,
#   80,
#   'S',
#   12),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28020',
#   'Nubes altas',
#   24,
#   24,
#   27.0,
#   0.0,
#   0,
#   60,
#   0,
#   80,
#   'S',
#   15),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28020',
#   'Nubes altas',
#   22,
#   22,
#   16.0,
#   0.0,
#   0,
#   60,
#   0,
#   80,
#   'S',
#   15),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28020',
#   'Cubierto',
#   21,
#   21,
#   26.0,
#   0.0,
#   0,
#   64,
#   0,
#   80,
#   'S',
#   7),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28020',
#   'Muy nuboso con tormenta y lluvia escasa',
#   21,
#   21,
#   23.0,
#   0.1,
#   0,
#   66,
#   0,
#   80,
#   'S',
#   15),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28020',
#   'Muy nuboso',
#   20,
#   20,
#   24.0,
#   0.0,
#   0,
#   50,
#   0,
#   80,
#   'S',
#   13),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28020',
#   'Cielo despejado',
#   20,
#   20,
#   12.0,
#   0.0,
#   0,
#   57,
#   0,
#   55,
#   'E',
#   6),
#  (Timestamp('2024-08-29 21:00:00'),
#   'id28020',
#   'Nubes altas',
#   19,
#   19,
#   9.0,
#   0.0,
#   0,
#   47,
#   0,
#   55,
#   'E',
#   7),
#  (Timestamp('2024-08-29 22:00:00'),
#   'id28020',
#   'Nubes altas',
#   18,
#   18,
#   5.0,
#   0.0,
#   0,
#   56,
#   0,
#   55,
#   'E',
#   4),
#  (Timestamp('2024-08-29 23:00:00'),
#   'id28020',
#   'Cubierto',
#   17,
#   17,
#   10.0,
#   0.0,
#   0,
#   67,
#   0,
#   55,
#   'E',
#   2),
#  (Timestamp('2024-08-30 00:00:00'),
#   'id28020',
#   'Cubierto con lluvia escasa',
#   16,
#   16,
#   9.0,
#   1.0,
#   0,
#   73,
#   0,
#   55,
#   'S',
#   7),
#  (Timestamp('2024-08-30 01:00:00'),
#   'id28020',
#   'Cubierto con lluvia',
#   16,
#   16,
#   15.0,
#   4.0,
#   0,
#   91,
#   0,
#   55,
#   'NE',
#   6),
#  (Timestamp('2024-08-30 02:00:00'),
#   'id28020',
#   'Cubierto',
#   15,
#   15,
#   10.0,
#   0.0,
#   0,
#   100,
#   0,
#   10,
#   'E',
#   10),
#  (Timestamp('2024-08-30 03:00:00'),
#   'id28020',
#   'Poco nuboso',
#   15,
#   15,
#   10.0,
#   0.0,
#   0,
#   100,
#   0,
#   10,
#   'NE',
#   4),
#  (Timestamp('2024-08-30 04:00:00'),
#   'id28020',
#   'Poco nuboso',
#   14,
#   14,
#   4.0,
#   0.0,
#   0,
#   100,
#   0,
#   10,
#   'N',
#   7),
#  (Timestamp('2024-08-30 05:00:00'),
#   'id28020',
#   'Poco nuboso',
#   14,
#   14,
#   5.0,
#   0.0,
#   0,
#   100,
#   0,
#   10,
#   'NO',
#   3),
#  (Timestamp('2024-08-30 06:00:00'),
#   'id28020',
#   'Cubierto',
#   14,
#   14,
#   8.0,
#   0.0,
#   0,
#   100,
#   0,
#   10,
#   'SE',
#   3),
#  (Timestamp('2024-08-30 07:00:00'),
#   'id28020',
#   'Cielo despejado',
#   13,
#   13,
#   9.0,
#   0.0,
#   0,
#   100,
#   0,
#   10,
#   'E',
#   3),
#  (Timestamp('2024-08-30 08:00:00'),
#   'id28020',
#   'Cielo despejado',
#   13,
#   13,
#   3.0,
#   0.0,
#   0,
#   100,
#   0,
#   50,
#   'N',
#   5),
#  (Timestamp('2024-08-30 09:00:00'),
#   'id28020',
#   'Cielo despejado',
#   16,
#   16,
#   10.0,
#   0.0,
#   0,
#   100,
#   0,
#   50,
#   'NE',
#   1),
#  (Timestamp('2024-08-30 10:00:00'),
#   'id28020',
#   'Cubierto',
#   19,
#   19,
#   26.0,
#   0.0,
#   0,
#   91,
#   0,
#   50,
#   'SO',
#   4),
#  (Timestamp('2024-08-30 11:00:00'),
#   'id28020',
#   'Cubierto con lluvia',
#   21,
#   21,
#   39.0,
#   8.0,
#   0,
#   76,
#   0,
#   50,
#   'S',
#   15),
#  (Timestamp('2024-08-30 12:00:00'),
#   'id28020',
#   'Cubierto con lluvia',
#   23,
#   23,
#   12.0,
#   7.0,
#   0,
#   67,
#   0,
#   50,
#   'SE',
#   24),
#  (Timestamp('2024-08-30 13:00:00'),
#   'id28020',
#   'Cubierto con lluvia escasa',
#   25,
#   25,
#   20.0,
#   2.0,
#   0,
#   57,
#   0,
#   50,
#   'S',
#   7),
#  (Timestamp('2024-08-30 14:00:00'),
#   'id28020',
#   'Nuboso',
#   26,
#   26,
#   16.0,
#   0.0,
#   0,
#   49,
#   0,
#   65,
#   'N',
#   12),
#  (Timestamp('2024-08-30 15:00:00'),
#   'id28020',
#   'Nubes altas',
#   27,
#   27,
#   12.0,
#   0.0,
#   0,
#   44,
#   0,
#   65,
#   'NE',
#   8),
#  (Timestamp('2024-08-30 16:00:00'),
#   'id28020',
#   'Nubes altas',
#   27,
#   27,
#   14.0,
#   0.0,
#   0,
#   40,
#   0,
#   65,
#   'O',
#   5),
#  (Timestamp('2024-08-30 17:00:00'),
#   'id28020',
#   'Nubes altas',
#   27,
#   27,
#   19.0,
#   0.0,
#   0,
#   39,
#   0,
#   65,
#   'SO',
#   6),
#  (Timestamp('2024-08-30 18:00:00'),
#   'id28020',
#   'Intervalos nubosos con lluvia escasa',
#   26,
#   26,
#   19.0,
#   0.1,
#   0,
#   40,
#   0,
#   65,
#   'S',
#   10),
#  (Timestamp('2024-08-30 19:00:00'),
#   'id28020',
#   'Poco nuboso',
#   25,
#   25,
#   13.0,
#   0.0,
#   0,
#   51,
#   0,
#   65,
#   'S',
#   11),
#  (Timestamp('2024-08-30 20:00:00'),
#   'id28020',
#   'Nubes altas',
#   23,
#   23,
#   5.0,
#   0.0,
#   0,
#   60,
#   0,
#   20,
#   'S',
#   6),
#  (Timestamp('2024-08-30 21:00:00'),
#   'id28020',
#   'Cielo despejado',
#   21,
#   21,
#   9.0,
#   0.0,
#   0,
#   72,
#   0,
#   20,
#   'NE',
#   4),
#  (Timestamp('2024-08-30 22:00:00'),
#   'id28020',
#   'Poco nuboso',
#   20,
#   20,
#   5.0,
#   0.0,
#   0,
#   76,
#   0,
#   20,
#   'E',
#   6),
#  (Timestamp('2024-08-30 23:00:00'),
#   'id28020',
#   'Cubierto',
#   18,
#   18,
#   5.0,
#   0.0,
#   0,
#   82,
#   0,
#   20,
#   'E',
#   3),
#  (Timestamp('2024-08-31 00:00:00'),
#   'id28020',
#   'Nuboso',
#   17,
#   17,
#   3.0,
#   0.0,
#   0,
#   87,
#   0,
#   20,
#   'SO',
#   3),
#  (Timestamp('2024-08-31 01:00:00'),
#   'id28020',
#   'Nuboso',
#   17,
#   17,
#   11.0,
#   0.0,
#   0,
#   93,
#   0,
#   20,
#   'SE',
#   2),
#  (Timestamp('2024-08-31 02:00:00'),
#   'id28020',
#   'Cielo despejado',
#   17,
#   17,
#   10.0,
#   0.0,
#   0,
#   87,
#   0,
#   0,
#   'E',
#   7),
#  (Timestamp('2024-08-31 03:00:00'),
#   'id28020',
#   'Poco nuboso',
#   16,
#   16,
#   15.0,
#   0.0,
#   0,
#   82,
#   0,
#   0,
#   'SE',
#   7),
#  (Timestamp('2024-08-31 04:00:00'),
#   'id28020',
#   'Poco nuboso',
#   15,
#   15,
#   6.0,
#   0.0,
#   0,
#   89,
#   0,
#   0,
#   'E',
#   6),
#  (Timestamp('2024-08-31 05:00:00'),
#   'id28020',
#   'Cielo despejado',
#   14,
#   14,
#   6.0,
#   0.0,
#   0,
#   96,
#   0,
#   0,
#   'NE',
#   4),
#  (Timestamp('2024-08-31 06:00:00'),
#   'id28020',
#   'Cielo despejado',
#   15,
#   15,
#   9.0,
#   0.0,
#   0,
#   89,
#   0,
#   0,
#   'NE',
#   5),
#  (Timestamp('2024-08-31 07:00:00'),
#   'id28020',
#   'Nubes altas',
#   14,
#   14,
#   11.0,
#   0.0,
#   0,
#   92,
#   0,
#   0,
#   'NE',
#   7),
#  (Timestamp('2024-08-29 12:00:00'),
#   'id28022',
#   'Intervalos nubosos con lluvia escasa',
#   24,
#   24,
#   21.0,
#   0.1,
#   0,
#   59,
#   0,
#   65,
#   'E',
#   9),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28022',
#   'Cubierto con lluvia escasa',
#   25,
#   25,
#   19.0,
#   0.1,
#   0,
#   54,
#   0,
#   65,
#   'E',
#   9),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28022',
#   'Nuboso',
#   27,
#   27,
#   22.0,
#   0.0,
#   0,
#   47,
#   0,
#   65,
#   'SE',
#   8),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28022',
#   'Cubierto',
#   26,
#   26,
#   19.0,
#   0.0,
#   0,
#   46,
#   0,
#   65,
#   'S',
#   10),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28022',
#   'Cubierto',
#   27,
#   27,
#   41.0,
#   0.0,
#   0,
#   43,
#   0,
#   65,
#   'SE',
#   8),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28022',
#   'Cubierto con lluvia escasa',
#   28,
#   28,
#   54.0,
#   0.1,
#   0,
#   44,
#   0,
#   65,
#   'SE',
#   25),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28022',
#   'Intervalos nubosos con lluvia',
#   25,
#   25,
#   25.0,
#   4.0,
#   0,
#   59,
#   0,
#   65,
#   'O',
#   34),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28022',
#   'Cubierto',
#   23,
#   23,
#   25.0,
#   0.0,
#   0,
#   73,
#   0,
#   65,
#   'NE',
#   14),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28022',
#   'Cubierto con lluvia escasa',
#   20,
#   20,
#   16.0,
#   0.1,
#   0,
#   82,
#   0,
#   65,
#   'N',
#   13),
#  (Timestamp('2024-08-29 21:00:00'),
#   'id28022',
#   'Muy nuboso',
#   21,
#   21,
#   20.0,
#   0.0,
#   0,
#   83,
#   0,
#   65,
#   'NE',
#   10),
#  (Timestamp('2024-08-29 22:00:00'),
#   'id28022',
#   'Nuboso',
#   18,
#   18,
#   32.0,
#   0.0,
#   0,
#   83,
#   0,
#   65,
#   'NE',
#   13),
#  (Timestamp('2024-08-29 23:00:00'),
#   'id28022',
#   'Nuboso',
#   19,
#   19,
#   30.0,
#   0.0,
#   0,
#   81,
#   0,
#   65,
#   'NE',
#   21),
#  (Timestamp('2024-08-30 00:00:00'),
#   'id28022',
#   'Muy nuboso',
#   18,
#   18,
#   36.0,
#   0.0,
#   0,
#   85,
#   0,
#   65,
#   'NE',
#   18),
#  (Timestamp('2024-08-30 01:00:00'),
#   'id28022',
#   'Muy nuboso',
#   18,
#   18,
#   27.0,
#   0.0,
#   0,
#   90,
#   0,
#   65,
#   'NE',
#   23),
#  (Timestamp('2024-08-30 02:00:00'),
#   'id28022',
#   'Poco nuboso',
#   18,
#   18,
#   38.0,
#   0.0,
#   0,
#   92,
#   0,
#   15,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 03:00:00'),
#   'id28022',
#   'Cubierto',
#   18,
#   18,
#   30.0,
#   0.0,
#   0,
#   91,
#   0,
#   15,
#   'NE',
#   25),
#  (Timestamp('2024-08-30 04:00:00'),
#   'id28022',
#   'Muy nuboso',
#   18,
#   18,
#   31.0,
#   0.0,
#   0,
#   91,
#   0,
#   15,
#   'NE',
#   20),
#  (Timestamp('2024-08-30 05:00:00'),
#   'id28022',
#   'Cubierto',
#   18,
#   18,
#   29.0,
#   0.0,
#   0,
#   90,
#   0,
#   15,
#   'NE',
#   20),
#  (Timestamp('2024-08-30 06:00:00'),
#   'id28022',
#   'Poco nuboso',
#   18,
#   18,
#   30.0,
#   0.0,
#   0,
#   94,
#   0,
#   15,
#   'NE',
#   19),
#  (Timestamp('2024-08-30 07:00:00'),
#   'id28022',
#   'Cielo despejado',
#   17,
#   17,
#   29.0,
#   0.0,
#   0,
#   95,
#   0,
#   15,
#   'NE',
#   20),
#  (Timestamp('2024-08-30 08:00:00'),
#   'id28022',
#   'Nuboso',
#   17,
#   17,
#   26.0,
#   0.0,
#   0,
#   100,
#   0,
#   20,
#   'NE',
#   19),
#  (Timestamp('2024-08-30 09:00:00'),
#   'id28022',
#   'Muy nuboso',
#   19,
#   19,
#   24.0,
#   0.0,
#   0,
#   91,
#   0,
#   20,
#   'NE',
#   17),
#  (Timestamp('2024-08-30 10:00:00'),
#   'id28022',
#   'Cubierto',
#   22,
#   22,
#   27.0,
#   0.0,
#   0,
#   81,
#   0,
#   20,
#   'E',
#   15),
#  (Timestamp('2024-08-30 11:00:00'),
#   'id28022',
#   'Cubierto',
#   24,
#   24,
#   50.0,
#   0.0,
#   0,
#   76,
#   0,
#   20,
#   'E',
#   15),
#  (Timestamp('2024-08-30 12:00:00'),
#   'id28022',
#   'Nuboso',
#   25,
#   25,
#   48.0,
#   0.0,
#   0,
#   67,
#   0,
#   20,
#   'E',
#   34),
#  (Timestamp('2024-08-30 13:00:00'),
#   'id28022',
#   'Nubes altas',
#   26,
#   26,
#   34.0,
#   0.0,
#   0,
#   60,
#   0,
#   20,
#   'N',
#   27),
#  (Timestamp('2024-08-30 14:00:00'),
#   'id28022',
#   'Muy nuboso',
#   27,
#   28,
#   31.0,
#   0.0,
#   0,
#   53,
#   0,
#   55,
#   'NE',
#   19),
#  (Timestamp('2024-08-30 15:00:00'),
#   'id28022',
#   'Muy nuboso',
#   28,
#   28,
#   29.0,
#   0.0,
#   0,
#   50,
#   0,
#   55,
#   'NE',
#   18),
#  (Timestamp('2024-08-30 16:00:00'),
#   'id28022',
#   'Nubes altas',
#   29,
#   29,
#   26.0,
#   0.0,
#   0,
#   44,
#   0,
#   55,
#   'E',
#   18),
#  (Timestamp('2024-08-30 17:00:00'),
#   'id28022',
#   'Poco nuboso',
#   30,
#   30,
#   26.0,
#   0.0,
#   0,
#   43,
#   0,
#   55,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 18:00:00'),
#   'id28022',
#   'Cielo despejado',
#   27,
#   27,
#   25.0,
#   0.0,
#   0,
#   50,
#   0,
#   55,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 19:00:00'),
#   'id28022',
#   'Intervalos nubosos con lluvia escasa',
#   25,
#   25,
#   19.0,
#   0.1,
#   0,
#   60,
#   0,
#   55,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 20:00:00'),
#   'id28022',
#   'Poco nuboso',
#   23,
#   23,
#   20.0,
#   0.0,
#   0,
#   73,
#   0,
#   20,
#   'NE',
#   12),
#  (Timestamp('2024-08-30 21:00:00'),
#   'id28022',
#   'Nubes altas',
#   23,
#   23,
#   24.0,
#   0.0,
#   0,
#   81,
#   0,
#   20,
#   'E',
#   10),
#  (Timestamp('2024-08-30 22:00:00'),
#   'id28022',
#   'Nubes altas',
#   21,
#   21,
#   23.0,
#   0.0,
#   0,
#   84,
#   0,
#   20,
#   'NE',
#   16),
#  (Timestamp('2024-08-30 23:00:00'),
#   'id28022',
#   'Cielo despejado',
#   20,
#   20,
#   21.0,
#   0.0,
#   0,
#   89,
#   0,
#   20,
#   'NE',
#   14),
#  (Timestamp('2024-08-31 00:00:00'),
#   'id28022',
#   'Poco nuboso',
#   20,
#   20,
#   20.0,
#   0.0,
#   0,
#   92,
#   0,
#   20,
#   'E',
#   14),
#  (Timestamp('2024-08-31 01:00:00'),
#   'id28022',
#   'Muy nuboso',
#   19,
#   19,
#   16.0,
#   0.0,
#   0,
#   92,
#   0,
#   20,
#   'NE',
#   13),
#  (Timestamp('2024-08-31 02:00:00'),
#   'id28022',
#   'Muy nuboso',
#   19,
#   19,
#   21.0,
#   0.0,
#   0,
#   89,
#   0,
#   5,
#   'NE',
#   10),
#  (Timestamp('2024-08-31 03:00:00'),
#   'id28022',
#   'Muy nuboso',
#   19,
#   19,
#   11.0,
#   0.0,
#   0,
#   86,
#   0,
#   5,
#   'E',
#   14),
#  (Timestamp('2024-08-31 04:00:00'),
#   'id28022',
#   'Cielo despejado',
#   19,
#   19,
#   23.0,
#   0.0,
#   0,
#   84,
#   0,
#   5,
#   'NE',
#   8),
#  (Timestamp('2024-08-31 05:00:00'),
#   'id28022',
#   'Cielo despejado',
#   18,
#   18,
#   16.0,
#   0.0,
#   0,
#   86,
#   0,
#   5,
#   'NE',
#   15),
#  (Timestamp('2024-08-31 06:00:00'),
#   'id28022',
#   'Poco nuboso',
#   18,
#   18,
#   13.0,
#   0.0,
#   0,
#   85,
#   0,
#   5,
#   'NE',
#   9),
#  (Timestamp('2024-08-31 07:00:00'),
#   'id28022',
#   'Nubes altas',
#   18,
#   18,
#   14.0,
#   0.0,
#   0,
#   88,
#   0,
#   5,
#   'NE',
#   8),
#  (Timestamp('2024-08-29 12:00:00'),
#   'id28023',
#   'Nubes altas',
#   23,
#   23,
#   27.0,
#   0.0,
#   0,
#   67,
#   0,
#   70,
#   'E',
#   13),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28023',
#   'Cubierto',
#   25,
#   25,
#   23.0,
#   0.0,
#   0,
#   56,
#   0,
#   70,
#   'E',
#   14),
#  (Timestamp('2024-08-29 14:00:00'),
#   'id28023',
#   'Nuboso',
#   25,
#   25,
#   25.0,
#   0.0,
#   0,
#   55,
#   0,
#   75,
#   'SE',
#   11),
#  (Timestamp('2024-08-29 15:00:00'),
#   'id28023',
#   'Muy nuboso',
#   23,
#   23,
#   23.0,
#   0.0,
#   0,
#   62,
#   0,
#   75,
#   'SE',
#   13),
#  (Timestamp('2024-08-29 16:00:00'),
#   'id28023',
#   'Muy nuboso',
#   26,
#   26,
#   25.0,
#   0.0,
#   0,
#   49,
#   0,
#   75,
#   'SE',
#   12),
#  (Timestamp('2024-08-29 17:00:00'),
#   'id28023',
#   'Cubierto',
#   25,
#   25,
#   41.0,
#   0.0,
#   0,
#   48,
#   0,
#   75,
#   'S',
#   13),
#  (Timestamp('2024-08-29 18:00:00'),
#   'id28023',
#   'Nuboso',
#   26,
#   26,
#   38.0,
#   0.0,
#   0,
#   53,
#   0,
#   75,
#   'SE',
#   23),
#  (Timestamp('2024-08-29 19:00:00'),
#   'id28023',
#   'Nuboso con tormenta y lluvia escasa',
#   20,
#   20,
#   7.0,
#   0.1,
#   0,
#   57,
#   0,
#   75,
#   'SE',
#   10),
#  (Timestamp('2024-08-29 20:00:00'),
#   'id28023',
#   'Cubierto',
#   20,
#   20,
#   9.0,
#   0.0,
#   0,
#   53,
#   0,
#   65,
#   'N',
#   4),
#  (Timestamp('2024-08-29 21:00:00'),
#   'id28023',
#   'Nubes altas',
#   19,
#   19,
#   6.0,
#   0.0,
#   0,
#   58,
#   0,
#   65,
#   'S',
#   3),
#  (Timestamp('2024-08-29 22:00:00'),
#   'id28023',
#   'Nuboso',
#   19,
#   19,
#   12.0,
#   0.0,
#   0,
#   65,
#   0,
#   65,
#   'NO',
#   4),
#  (Timestamp('2024-08-29 23:00:00'),
#   'id28023',
#   'Intervalos nubosos con lluvia escasa',
#   18,
#   18,
#   14.0,
#   0.1,
#   0,
#   71,
#   0,
#   65,
#   'E',
#   5),
#  (Timestamp('2024-08-30 00:00:00'),
#   'id28023',
#   'Nuboso',
#   17,
#   17,
#   21.0,
#   0.0,
#   0,
#   74,
#   0,
#   65,
#   'E',
#   8),
#  (Timestamp('2024-08-30 01:00:00'),
#   'id28023',
#   'Nuboso',
#   17,
#   17,
#   8.0,
#   0.0,
#   0,
#   82,
#   0,
#   65,
#   'E',
#   12),
#  (Timestamp('2024-08-30 02:00:00'),
#   'id28023',
#   'Poco nuboso',
#   16,
#   16,
#   15.0,
#   0.0,
#   0,
#   79,
#   0,
#   15,
#   'SE',
#   6),
#  (Timestamp('2024-08-30 03:00:00'),
#   'id28023',
#   'Muy nuboso',
#   16,
#   16,
#   13.0,
#   0.0,
#   0,
#   82,
#   0,
#   15,
#   'E',
#   9),
#  (Timestamp('2024-08-30 04:00:00'),
#   'id28023',
#   'Muy nuboso',
#   17,
#   17,
#   21.0,
#   0.0,
#   0,
#   87,
#   0,
#   15,
#   'E',
#   9),
#  (Timestamp('2024-08-30 05:00:00'),
#   'id28023',
#   'Nuboso',
#   17,
#   17,
#   22.0,
#   0.0,
#   0,
#   84,
#   0,
#   15,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 06:00:00'),
#   'id28023',
#   'Nuboso',
#   17,
#   17,
#   24.0,
#   0.0,
#   0,
#   90,
#   0,
#   15,
#   'NE',
#   14),
#  (Timestamp('2024-08-30 07:00:00'),
#   'id28023',
#   'Cielo despejado',
#   17,
#   17,
#   20.0,
#   0.0,
#   0,
#   94,
#   0,
#   15,
#   'NE',
#   15),
#  (Timestamp('2024-08-30 08:00:00'),
#   'id28023',
#   'Cielo despejado',
#   17,
#   17,
#   18.0,
#   0.0,
#   0,
#   99,
#   0,
#   55,
#   'NE',
#   13),
#  (Timestamp('2024-08-30 09:00:00'),
#   'id28023',
#   'Poco nuboso',
#   19,
#   19,
#   26.0,
#   0.0,
#   0,
#   90,
#   0,
#   55,
#   'E',
#   11),
#  (Timestamp('2024-08-30 10:00:00'),
#   'id28023',
#   'Cubierto',
#   20,
#   20,
#   30.0,
#   0.0,
#   0,
#   81,
#   0,
#   55,
#   'E',
#   14),
#  (Timestamp('2024-08-30 11:00:00'),
#   'id28023',
#   'Cubierto con lluvia escasa',
#   22,
#   22,
#   28.0,
#   1.0,
#   0,
#   74,
#   0,
#   55,
#   'E',
#   18),
#  (Timestamp('2024-08-30 12:00:00'),
#   'id28023',
#   'Cubierto con lluvia',
#   24,
#   24,
#   37.0,
#   29.0,
#   0,
#   76,
#   0,
#   55,
#   'E',
#   18),
#  (Timestamp('2024-08-30 13:00:00'),
#   'id28023',
#   'Intervalos nubosos con lluvia',
#   25,
#   25,
#   15.0,
#   4.0,
#   0,
#   55,
#   0,
#   55,
#   'N',
#   10),
#  (Timestamp('2024-08-30 14:00:00'),
#   'id28023',
#   'Nubes altas',
#   27,
#   27,
#   13.0,
#   0.0,
#   0,
#   49,
#   0,
#   65,
#   'SE',
#   10),
#  (Timestamp('2024-08-30 15:00:00'),
#   'id28023',
#   'Intervalos nubosos con lluvia escasa',
#   27,
#   27,
#   12.0,
#   0.1,
#   0,
#   47,
#   0,
#   65,
#   'E',
#   5),
#  (Timestamp('2024-08-30 16:00:00'),
#   'id28023',
#   'Intervalos nubosos con lluvia escasa',
#   28,
#   28,
#   15.0,
#   0.1,
#   0,
#   44,
#   0,
#   65,
#   'E',
#   5),
#  (Timestamp('2024-08-30 17:00:00'),
#   'id28023',
#   'Poco nuboso',
#   28,
#   28,
#   18.0,
#   0.0,
#   0,
#   45,
#   0,
#   65,
#   'E',
#   6),
#  ...]

# %%
query_insercion = """INSERT INTO weather (fecha, id_municipio, cielo, temp_celsius, sen_termica_celsius, racha_max_km_h, precipitacion_mm, nieve_mm, humedad_relativa_pct, prob_de_nieve_pct, prob_de_tormenta_pct, direccion_viento, velocidad_viento
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);"""
cursor.executemany(query_insercion, aemet_values) # cuando se quieren insertar varios
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# Cell In[480], line 3
#       1 query_insercion = """INSERT INTO weather (fecha, id_municipio, cielo, temp_celsius, sen_termica_celsius, racha_max_km_h, precipitacion_mm, nieve_mm, humedad_relativa_pct, prob_de_nieve_pct, prob_de_tormenta_pct, direccion_viento, velocidad_viento
#       2 ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);"""
# ----> 3 cursor.executemany(query_insercion, aemet_values) # cuando se quieren insertar varios
#       4 connection.commit()
#
# ForeignKeyViolation: inserción o actualización en la tabla «weather» viola la llave foránea «weather_id_municipio_fkey»
# DETAIL:  La llave (id_municipio)=(id28030) no está presente en la tabla «municipios».

# %% [markdown]
# It seems that there's an id that is not present in the municipios dataset. So let's check if the value is really there or not, if it is not, it should be dropped.

# %%
municipios_df[municipios_df["id_municipio"]=="id28030"]
# Out:
# Empty DataFrame
# Columns: [municipio_normalizado, latitude, longitude, municipio, id_municipio]
# Index: []

# %% [markdown]
# It is indeed not there, so it should be dropped directly, as the municipio is not being monitored in the database.

# %%
lista_id_municipio = list(municipios_df["id_municipio"].unique())

aemet_df = aemet_df[aemet_df["id_municipio"].isin(lista_id_municipio)]

aemet_values = [tuple(value_row) for value_row in aemet_df.values]
aemet_values[:2]
# Out:
# [(Timestamp('2024-08-29 12:00:00'),
#   'id28001',
#   'Nubes altas',
#   21,
#   21,
#   25.0,
#   0.0,
#   0,
#   69,
#   0,
#   75,
#   'S',
#   7),
#  (Timestamp('2024-08-29 13:00:00'),
#   'id28001',
#   'Nubes altas',
#   24,
#   24,
#   29.0,
#   0.0,
#   0,
#   57,
#   0,
#   75,
#   'SE',
#   12)]

# %%
connection = connect_to_database("modulo4_lab3",credentials_dict=database_credentials)
cursor = connection.cursor()

query_insercion = """INSERT INTO weather (fecha, id_municipio, cielo, temp_celsius, sen_termica_celsius, racha_max_km_h, precipitacion_mm, nieve_mm, humedad_relativa_pct, prob_de_nieve_pct, prob_de_tormenta_pct, direccion_viento, velocidad_viento)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);"""
cursor.executemany(query_insercion, aemet_values) # cuando se quieren insertar varios
connection.commit()
